# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key from config.py file.
from config import weather_api_key
# Import the time module.
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Import gmaps module
#import gmaps
# Import the API key.
#from config import g_key

# %%
# Configure gmaps to use your Google API key. You only have to do this once
#gmaps.configure(api_key=g_key)

# %%
##############################
# Part 1: Module 6 Challenge #
##############################

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations. Use zip() to pair them.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates= list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Create an empty list to hold the weather data.
city_data = []
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # % is modulo: the remainder from the division of the first argument to the second
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
   
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descr = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
            print('Rain KeyError Received for: ', city)
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:
            city_snow = 0
            print('Snow KeyError Received for: ', city)
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descr,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Snow KeyError Received for:  bluff
# Processing Record 2 of Set 1 | atuona
# Snow KeyError Received for:  atuona
# Processing Record 3 of Set 1 | pathein
# Snow KeyError Received for:  pathein
# Processing Record 4 of Set 1 | smithers
# Rain KeyError Received for:  smithers
# Snow KeyError Received for:  smithers
# Processing Record 5 of Set 1 | pochutla
# Rain KeyError Received for:  pochutla
# Snow KeyError Received for:  pochutla
# Processing Record 6 of Set 1 | sakakah
# Rain KeyError Received for:  sakakah
# Snow KeyError Received for:  sakakah
# Processing Record 7 of Set 1 | sarkand
# Snow KeyError Received for:  sarkand
# Processing Record 8 of Set 1 | kahului
# Rain KeyError Received for:  kahului
# Snow KeyError Received for:  kahului
# Processing Record 9 of Set 1 | arraial do cabo
# Rain KeyError Received for:  arraial do cabo
# Snow KeyError Received for:  arraial do cabo
# Processing Record 10 of Set 1 | mahebourg
# Rain KeyError Received for:  mahebourg
# Snow KeyError Received for:  mahebourg
# Processing Record 11 of Set 1 | punta arenas
# Rain KeyError Received for:  punta arenas
# Snow KeyError Received for:  punta arenas
# Processing Record 12 of Set 1 | vaini
# Rain KeyError Received for:  vaini
# Snow KeyError Received for:  vaini
# Processing Record 13 of Set 1 | carnarvon
# Rain KeyError Received for:  carnarvon
# Snow KeyError Received for:  carnarvon
# Processing Record 14 of Set 1 | ahipara
# Rain KeyError Received for:  ahipara
# Snow KeyError Received for:  ahipara
# Processing Record 15 of Set 1 | harnai
# Rain KeyError Received for:  harnai
# Snow KeyError Received for:  harnai
# Processing Record 16 of Set 1 | iqaluit
# Rain KeyError Received for:  iqaluit
# Snow KeyError Received for:  iqaluit
# Processing Record 17 of Set 1 | biltine
# Rain KeyError Received for:  biltine
# Snow KeyError Received for:  biltine
# Processing Record 18 of Set 1 | berbera
# Rain KeyError Received for:  berbera
# Snow KeyError Received for:  berbera
# Processing Record 19 of Set 1 | pangnirtung
# Rain KeyError Received for:  pangnirtung
# Snow KeyError Received for:  pangnirtung
# Processing Record 20 of Set 1 | hermanus
# Rain KeyError Received for:  hermanus
# Snow KeyError Received for:  hermanus
# Processing Record 21 of Set 1 | port alfred
# Rain KeyError Received for:  port alfred
# Snow KeyError Received for:  port alfred
# Processing Record 22 of Set 1 | mataura
# Snow KeyError Received for:  mataura
# Processing Record 23 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 1 | lagoa
# Rain KeyError Received for:  lagoa
# Snow KeyError Received for:  lagoa
# Processing Record 25 of Set 1 | cape town
# Rain KeyError Received for:  cape town
# Snow KeyError Received for:  cape town
# Processing Record 26 of Set 1 | mandali
# Rain KeyError Received for:  mandali
# Snow KeyError Received for:  mandali
# Processing Record 27 of Set 1 | rikitea
# Rain KeyError Received for:  rikitea
# Snow KeyError Received for:  rikitea
# Processing Record 28 of Set 1 | tawzar
# City not found. Skipping...
# Processing Record 29 of Set 1 | thompson
# Rain KeyError Received for:  thompson
# Snow KeyError Received for:  thompson
# Processing Record 30 of Set 1 | upernavik
# Rain KeyError Received for:  upernavik
# Snow KeyError Received for:  upernavik
# Processing Record 31 of Set 1 | keti bandar
# Rain KeyError Received for:  keti bandar
# Snow KeyError Received for:  keti bandar
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | dikson
# Snow KeyError Received for:  dikson
# Processing Record 34 of Set 1 | gladstone
# Rain KeyError Received for:  gladstone
# Snow KeyError Received for:  gladstone
# Processing Record 35 of Set 1 | ribeira grande
# Rain KeyError Received for:  ribeira grande
# Snow KeyError Received for:  ribeira grande
# Processing Record 36 of Set 1 | wilson
# Rain KeyError Received for:  wilson
# Snow KeyError Received for:  wilson
# Processing Record 37 of Set 1 | gat
# Rain KeyError Received for:  gat
# Snow KeyError Received for:  gat
# Processing Record 38 of Set 1 | luanda
# Rain KeyError Received for:  luanda
# Snow KeyError Received for:  luanda
# Processing Record 39 of Set 1 | jackson
# Rain KeyError Received for:  jackson
# Snow KeyError Received for:  jackson
# Processing Record 40 of Set 1 | tapah
# Rain KeyError Received for:  tapah
# Snow KeyError Received for:  tapah
# Processing Record 41 of Set 1 | lake charles
# Rain KeyError Received for:  lake charles
# Snow KeyError Received for:  lake charles
# Processing Record 42 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 1 | shushtar
# Rain KeyError Received for:  shushtar
# Snow KeyError Received for:  shushtar
# Processing Record 44 of Set 1 | tual
# Snow KeyError Received for:  tual
# Processing Record 45 of Set 1 | ponta do sol
# Rain KeyError Received for:  ponta do sol
# Snow KeyError Received for:  ponta do sol
# Processing Record 46 of Set 1 | mar del plata
# Rain KeyError Received for:  mar del plata
# Snow KeyError Received for:  mar del plata
# Processing Record 47 of Set 1 | nongan
# Rain KeyError Received for:  nongan
# Snow KeyError Received for:  nongan
# Processing Record 48 of Set 1 | chuy
# Rain KeyError Received for:  chuy
# Snow KeyError Received for:  chuy
# Processing Record 49 of Set 1 | le mars
# Rain KeyError Received for:  le mars
# Snow KeyError Received for:  le mars
# Processing Record 50 of Set 1 | goderich
# Rain KeyError Received for:  goderich
# Snow KeyError Received for:  goderich
# Processing Record 1 of Set 2 | ushuaia
# Rain KeyError Received for:  ushuaia
# Snow KeyError Received for:  ushuaia
# Processing Record 2 of Set 2 | booue
# Rain KeyError Received for:  booue
# Snow KeyError Received for:  booue
# Processing Record 3 of Set 2 | albany
# Rain KeyError Received for:  albany
# Snow KeyError Received for:  albany
# Processing Record 4 of Set 2 | chichawatni
# Snow KeyError Received for:  chichawatni
# Processing Record 5 of Set 2 | hilo
# Rain KeyError Received for:  hilo
# Snow KeyError Received for:  hilo
# Processing Record 6 of Set 2 | pouebo
# Rain KeyError Received for:  pouebo
# Snow KeyError Received for:  pouebo
# Processing Record 7 of Set 2 | castro
# Rain KeyError Received for:  castro
# Snow KeyError Received for:  castro
# Processing Record 8 of Set 2 | hobart
# Rain KeyError Received for:  hobart
# Snow KeyError Received for:  hobart
# Processing Record 9 of Set 2 | hualmay
# Rain KeyError Received for:  hualmay
# Snow KeyError Received for:  hualmay
# Processing Record 10 of Set 2 | busselton
# Rain KeyError Received for:  busselton
# Snow KeyError Received for:  busselton
# Processing Record 11 of Set 2 | butaritari
# Snow KeyError Received for:  butaritari
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | tuktoyaktuk
# Rain KeyError Received for:  tuktoyaktuk
# Snow KeyError Received for:  tuktoyaktuk
# Processing Record 14 of Set 2 | georgetown
# Rain KeyError Received for:  georgetown
# Snow KeyError Received for:  georgetown
# Processing Record 15 of Set 2 | arlit
# Rain KeyError Received for:  arlit
# Snow KeyError Received for:  arlit
# Processing Record 16 of Set 2 | nanortalik
# Rain KeyError Received for:  nanortalik
# Snow KeyError Received for:  nanortalik
# Processing Record 17 of Set 2 | luau
# Rain KeyError Received for:  luau
# Snow KeyError Received for:  luau
# Processing Record 18 of Set 2 | show low
# Rain KeyError Received for:  show low
# Snow KeyError Received for:  show low
# Processing Record 19 of Set 2 | moose factory
# Rain KeyError Received for:  moose factory
# Snow KeyError Received for:  moose factory
# Processing Record 20 of Set 2 | te anau
# Rain KeyError Received for:  te anau
# Snow KeyError Received for:  te anau
# Processing Record 21 of Set 2 | airai
# Rain KeyError Received for:  airai
# Snow KeyError Received for:  airai
# Processing Record 22 of Set 2 | jamestown
# Rain KeyError Received for:  jamestown
# Snow KeyError Received for:  jamestown
# Processing Record 23 of Set 2 | port hedland
# Rain KeyError Received for:  port hedland
# Snow KeyError Received for:  port hedland
# Processing Record 24 of Set 2 | izhma
# Rain KeyError Received for:  izhma
# Snow KeyError Received for:  izhma
# Processing Record 25 of Set 2 | avarua
# Snow KeyError Received for:  avarua
# Processing Record 26 of Set 2 | sao filipe
# Rain KeyError Received for:  sao filipe
# Snow KeyError Received for:  sao filipe
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | ngunguru
# Rain KeyError Received for:  ngunguru
# Snow KeyError Received for:  ngunguru
# Processing Record 29 of Set 2 | ayan
# Rain KeyError Received for:  ayan
# Snow KeyError Received for:  ayan
# Processing Record 30 of Set 2 | sept-iles
# Rain KeyError Received for:  sept-iles
# Snow KeyError Received for:  sept-iles
# Processing Record 31 of Set 2 | laguna
# Rain KeyError Received for:  laguna
# Snow KeyError Received for:  laguna
# Processing Record 32 of Set 2 | tamiahua
# Rain KeyError Received for:  tamiahua
# Snow KeyError Received for:  tamiahua
# Processing Record 33 of Set 2 | nome
# Rain KeyError Received for:  nome
# Snow KeyError Received for:  nome
# Processing Record 34 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 2 | bethel
# Rain KeyError Received for:  bethel
# Snow KeyError Received for:  bethel
# Processing Record 36 of Set 2 | barrow
# Rain KeyError Received for:  barrow
# Snow KeyError Received for:  barrow
# Processing Record 37 of Set 2 | ornes
# Rain KeyError Received for:  ornes
# Snow KeyError Received for:  ornes
# Processing Record 38 of Set 2 | pombas
# Rain KeyError Received for:  pombas
# Snow KeyError Received for:  pombas
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | hofn
# Rain KeyError Received for:  hofn
# Snow KeyError Received for:  hofn
# Processing Record 41 of Set 2 | chokurdakh
# Rain KeyError Received for:  chokurdakh
# Snow KeyError Received for:  chokurdakh
# Processing Record 42 of Set 2 | bay roberts
# Rain KeyError Received for:  bay roberts
# Snow KeyError Received for:  bay roberts
# Processing Record 43 of Set 2 | san patricio
# Rain KeyError Received for:  san patricio
# Snow KeyError Received for:  san patricio
# Processing Record 44 of Set 2 | solhan
# Rain KeyError Received for:  solhan
# Snow KeyError Received for:  solhan
# Processing Record 45 of Set 2 | ilulissat
# Rain KeyError Received for:  ilulissat
# Snow KeyError Received for:  ilulissat
# Processing Record 46 of Set 2 | urengoy
# Rain KeyError Received for:  urengoy
# Snow KeyError Received for:  urengoy
# Processing Record 47 of Set 2 | esil
# Snow KeyError Received for:  esil
# Processing Record 48 of Set 2 | clyde river
# Rain KeyError Received for:  clyde river
# Snow KeyError Received for:  clyde river
# Processing Record 49 of Set 2 | maua
# Rain KeyError Received for:  maua
# Snow KeyError Received for:  maua
# Processing Record 50 of Set 2 | alim
# Snow KeyError Received for:  alim
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | torbay
# Rain KeyError Received for:  torbay
# Snow KeyError Received for:  torbay
# Processing Record 3 of Set 3 | arawa
# Rain KeyError Received for:  arawa
# Snow KeyError Received for:  arawa
# Processing Record 4 of Set 3 | bengkulu
# Rain KeyError Received for:  bengkulu
# Snow KeyError Received for:  bengkulu
# Processing Record 5 of Set 3 | yamada
# Snow KeyError Received for:  yamada
# Processing Record 6 of Set 3 | saint-augustin
# Rain KeyError Received for:  saint-augustin
# Snow KeyError Received for:  saint-augustin
# Processing Record 7 of Set 3 | hovd
# Rain KeyError Received for:  hovd
# Snow KeyError Received for:  hovd
# Processing Record 8 of Set 3 | santa cruz
# Rain KeyError Received for:  santa cruz
# Snow KeyError Received for:  santa cruz
# Processing Record 9 of Set 3 | honiara
# Rain KeyError Received for:  honiara
# Snow KeyError Received for:  honiara
# Processing Record 10 of Set 3 | puerto escondido
# Snow KeyError Received for:  puerto escondido
# Processing Record 11 of Set 3 | qaanaaq
# Rain KeyError Received for:  qaanaaq
# Snow KeyError Received for:  qaanaaq
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | bredy
# Snow KeyError Received for:  bredy
# Processing Record 14 of Set 3 | narsaq
# Rain KeyError Received for:  narsaq
# Snow KeyError Received for:  narsaq
# Processing Record 15 of Set 3 | salalah
# Rain KeyError Received for:  salalah
# Snow KeyError Received for:  salalah
# Processing Record 16 of Set 3 | bredasdorp
# Rain KeyError Received for:  bredasdorp
# Snow KeyError Received for:  bredasdorp
# Processing Record 17 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 3 | general roca
# Rain KeyError Received for:  general roca
# Snow KeyError Received for:  general roca
# Processing Record 19 of Set 3 | noumea
# Rain KeyError Received for:  noumea
# Snow KeyError Received for:  noumea
# Processing Record 20 of Set 3 | east london
# Rain KeyError Received for:  east london
# Snow KeyError Received for:  east london
# Processing Record 21 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 22 of Set 3 | wanaka
# Snow KeyError Received for:  wanaka
# Processing Record 23 of Set 3 | riyadh
# Rain KeyError Received for:  riyadh
# Snow KeyError Received for:  riyadh
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | puerto ayora
# Rain KeyError Received for:  puerto ayora
# Snow KeyError Received for:  puerto ayora
# Processing Record 26 of Set 3 | buin
# Rain KeyError Received for:  buin
# Snow KeyError Received for:  buin
# Processing Record 27 of Set 3 | mount gambier
# Rain KeyError Received for:  mount gambier
# Snow KeyError Received for:  mount gambier
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | pandan
# Rain KeyError Received for:  pandan
# Snow KeyError Received for:  pandan
# Processing Record 30 of Set 3 | sorkjosen
# Snow KeyError Received for:  sorkjosen
# Processing Record 31 of Set 3 | borova
# Rain KeyError Received for:  borova
# Snow KeyError Received for:  borova
# Processing Record 32 of Set 3 | port elizabeth
# Rain KeyError Received for:  port elizabeth
# Snow KeyError Received for:  port elizabeth
# Processing Record 33 of Set 3 | bumba
# Snow KeyError Received for:  bumba
# Processing Record 34 of Set 3 | cherskiy
# Rain KeyError Received for:  cherskiy
# Snow KeyError Received for:  cherskiy
# Processing Record 35 of Set 3 | ancud
# Rain KeyError Received for:  ancud
# Snow KeyError Received for:  ancud
# Processing Record 36 of Set 3 | baykalovo
# Rain KeyError Received for:  baykalovo
# Snow KeyError Received for:  baykalovo
# Processing Record 37 of Set 3 | kapit
# Rain KeyError Received for:  kapit
# Snow KeyError Received for:  kapit
# Processing Record 38 of Set 3 | cheremnoye
# Rain KeyError Received for:  cheremnoye
# Snow KeyError Received for:  cheremnoye
# Processing Record 39 of Set 3 | sydney
# Snow KeyError Received for:  sydney
# Processing Record 40 of Set 3 | tasiilaq
# Rain KeyError Received for:  tasiilaq
# Snow KeyError Received for:  tasiilaq
# Processing Record 41 of Set 3 | fredericksburg
# Rain KeyError Received for:  fredericksburg
# Snow KeyError Received for:  fredericksburg
# Processing Record 42 of Set 3 | flinders
# Snow KeyError Received for:  flinders
# Processing Record 43 of Set 3 | sitka
# Rain KeyError Received for:  sitka
# Snow KeyError Received for:  sitka
# Processing Record 44 of Set 3 | peniche
# Rain KeyError Received for:  peniche
# Snow KeyError Received for:  peniche
# Processing Record 45 of Set 3 | adrar
# Rain KeyError Received for:  adrar
# Snow KeyError Received for:  adrar
# Processing Record 46 of Set 3 | viedma
# Snow KeyError Received for:  viedma
# Processing Record 47 of Set 3 | kapaa
# Rain KeyError Received for:  kapaa
# Snow KeyError Received for:  kapaa
# Processing Record 48 of Set 3 | provideniya
# Rain KeyError Received for:  provideniya
# Snow KeyError Received for:  provideniya
# Processing Record 49 of Set 3 | jalu
# Rain KeyError Received for:  jalu
# Snow KeyError Received for:  jalu
# Processing Record 50 of Set 3 | tambopata
# Rain KeyError Received for:  tambopata
# Snow KeyError Received for:  tambopata
# Processing Record 1 of Set 4 | beringovskiy
# Rain KeyError Received for:  beringovskiy
# Snow KeyError Received for:  beringovskiy
# Processing Record 2 of Set 4 | san cristobal
# Rain KeyError Received for:  san cristobal
# Snow KeyError Received for:  san cristobal
# Processing Record 3 of Set 4 | springbok
# Rain KeyError Received for:  springbok
# Snow KeyError Received for:  springbok
# Processing Record 4 of Set 4 | gwanda
# Rain KeyError Received for:  gwanda
# Snow KeyError Received for:  gwanda
# Processing Record 5 of Set 4 | shetpe
# Rain KeyError Received for:  shetpe
# Snow KeyError Received for:  shetpe
# Processing Record 6 of Set 4 | tiksi
# Rain KeyError Received for:  tiksi
# Snow KeyError Received for:  tiksi
# Processing Record 7 of Set 4 | juba
# Rain KeyError Received for:  juba
# Snow KeyError Received for:  juba
# Processing Record 8 of Set 4 | hambantota
# Rain KeyError Received for:  hambantota
# Snow KeyError Received for:  hambantota
# Processing Record 9 of Set 4 | kodiak
# Rain KeyError Received for:  kodiak
# Snow KeyError Received for:  kodiak
# Processing Record 10 of Set 4 | kavieng
# Rain KeyError Received for:  kavieng
# Snow KeyError Received for:  kavieng
# Processing Record 11 of Set 4 | changji
# Rain KeyError Received for:  changji
# Snow KeyError Received for:  changji
# Processing Record 12 of Set 4 | saint-philippe
# Rain KeyError Received for:  saint-philippe
# Snow KeyError Received for:  saint-philippe
# Processing Record 13 of Set 4 | saldanha
# Rain KeyError Received for:  saldanha
# Snow KeyError Received for:  saldanha
# Processing Record 14 of Set 4 | muros
# Rain KeyError Received for:  muros
# Snow KeyError Received for:  muros
# Processing Record 15 of Set 4 | teya
# Rain KeyError Received for:  teya
# Snow KeyError Received for:  teya
# Processing Record 16 of Set 4 | vanimo
# Rain KeyError Received for:  vanimo
# Snow KeyError Received for:  vanimo
# Processing Record 17 of Set 4 | yeppoon
# Rain KeyError Received for:  yeppoon
# Snow KeyError Received for:  yeppoon
# Processing Record 18 of Set 4 | cayenne
# Snow KeyError Received for:  cayenne
# Processing Record 19 of Set 4 | bambous virieux
# Rain KeyError Received for:  bambous virieux
# Snow KeyError Received for:  bambous virieux
# Processing Record 20 of Set 4 | akyab
# Snow KeyError Received for:  akyab
# Processing Record 21 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 4 | ryotsu
# Rain KeyError Received for:  ryotsu
# Snow KeyError Received for:  ryotsu
# Processing Record 23 of Set 4 | tignere
# Snow KeyError Received for:  tignere
# Processing Record 24 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 4 | tabuk
# Rain KeyError Received for:  tabuk
# Snow KeyError Received for:  tabuk
# Processing Record 27 of Set 4 | ekibastuz
# Rain KeyError Received for:  ekibastuz
# Snow KeyError Received for:  ekibastuz
# Processing Record 28 of Set 4 | astana
# Rain KeyError Received for:  astana
# Snow KeyError Received for:  astana
# Processing Record 29 of Set 4 | penzance
# Rain KeyError Received for:  penzance
# Snow KeyError Received for:  penzance
# Processing Record 30 of Set 4 | beruwala
# Rain KeyError Received for:  beruwala
# Snow KeyError Received for:  beruwala
# Processing Record 31 of Set 4 | maumere
# Rain KeyError Received for:  maumere
# Snow KeyError Received for:  maumere
# Processing Record 32 of Set 4 | richards bay
# Snow KeyError Received for:  richards bay
# Processing Record 33 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 34 of Set 4 | geraldton
# Rain KeyError Received for:  geraldton
# Snow KeyError Received for:  geraldton
# Processing Record 35 of Set 4 | pisco
# Rain KeyError Received for:  pisco
# Snow KeyError Received for:  pisco
# Processing Record 36 of Set 4 | vardo
# Rain KeyError Received for:  vardo
# Snow KeyError Received for:  vardo
# Processing Record 37 of Set 4 | gunjur
# Rain KeyError Received for:  gunjur
# Snow KeyError Received for:  gunjur
# Processing Record 38 of Set 4 | aswan
# Rain KeyError Received for:  aswan
# Snow KeyError Received for:  aswan
# Processing Record 39 of Set 4 | kaitangata
# Rain KeyError Received for:  kaitangata
# Snow KeyError Received for:  kaitangata
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | new norfolk
# Rain KeyError Received for:  new norfolk
# Snow KeyError Received for:  new norfolk
# Processing Record 42 of Set 4 | havre-saint-pierre
# Rain KeyError Received for:  havre-saint-pierre
# Snow KeyError Received for:  havre-saint-pierre
# Processing Record 43 of Set 4 | saskylakh
# Rain KeyError Received for:  saskylakh
# Snow KeyError Received for:  saskylakh
# Processing Record 44 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 4 | harer
# Snow KeyError Received for:  harer
# Processing Record 46 of Set 4 | kulhudhuffushi
# Snow KeyError Received for:  kulhudhuffushi
# Processing Record 47 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 49 of Set 4 | corcoran
# Rain KeyError Received for:  corcoran
# Snow KeyError Received for:  corcoran
# Processing Record 50 of Set 4 | touros
# Rain KeyError Received for:  touros
# Snow KeyError Received for:  touros
# Processing Record 1 of Set 5 | tautira
# Rain KeyError Received for:  tautira
# Snow KeyError Received for:  tautira
# Processing Record 2 of Set 5 | marzuq
# Rain KeyError Received for:  marzuq
# Snow KeyError Received for:  marzuq
# Processing Record 3 of Set 5 | novikovo
# Rain KeyError Received for:  novikovo
# Snow KeyError Received for:  novikovo
# Processing Record 4 of Set 5 | san borja
# Rain KeyError Received for:  san borja
# Snow KeyError Received for:  san borja
# Processing Record 5 of Set 5 | sinnamary
# Rain KeyError Received for:  sinnamary
# Snow KeyError Received for:  sinnamary
# Processing Record 6 of Set 5 | caravelas
# Rain KeyError Received for:  caravelas
# Snow KeyError Received for:  caravelas
# Processing Record 7 of Set 5 | sao jose da coroa grande
# Snow KeyError Received for:  sao jose da coroa grande
# Processing Record 8 of Set 5 | key largo
# Snow KeyError Received for:  key largo
# Processing Record 9 of Set 5 | bud
# Rain KeyError Received for:  bud
# Snow KeyError Received for:  bud
# Processing Record 10 of Set 5 | kholmskaya
# Rain KeyError Received for:  kholmskaya
# Snow KeyError Received for:  kholmskaya
# Processing Record 11 of Set 5 | robertsport
# Rain KeyError Received for:  robertsport
# Snow KeyError Received for:  robertsport
# Processing Record 12 of Set 5 | kloulklubed
# Rain KeyError Received for:  kloulklubed
# Snow KeyError Received for:  kloulklubed
# Processing Record 13 of Set 5 | tambaliza
# City not found. Skipping...
# Processing Record 14 of Set 5 | kaseda
# Rain KeyError Received for:  kaseda
# Snow KeyError Received for:  kaseda
# Processing Record 15 of Set 5 | pakokku
# Rain KeyError Received for:  pakokku
# Snow KeyError Received for:  pakokku
# Processing Record 16 of Set 5 | opuwo
# Rain KeyError Received for:  opuwo
# Snow KeyError Received for:  opuwo
# Processing Record 17 of Set 5 | tipuani
# Rain KeyError Received for:  tipuani
# Snow KeyError Received for:  tipuani
# Processing Record 18 of Set 5 | bayburt
# Rain KeyError Received for:  bayburt
# Snow KeyError Received for:  bayburt
# Processing Record 19 of Set 5 | ivankiv
# Rain KeyError Received for:  ivankiv
# Snow KeyError Received for:  ivankiv
# Processing Record 20 of Set 5 | aleksandriya
# Rain KeyError Received for:  aleksandriya
# Snow KeyError Received for:  aleksandriya
# Processing Record 21 of Set 5 | norman wells
# Rain KeyError Received for:  norman wells
# Snow KeyError Received for:  norman wells
# Processing Record 22 of Set 5 | trelew
# Rain KeyError Received for:  trelew
# Snow KeyError Received for:  trelew
# Processing Record 23 of Set 5 | kandrian
# Snow KeyError Received for:  kandrian
# Processing Record 24 of Set 5 | klaksvik
# Rain KeyError Received for:  klaksvik
# Snow KeyError Received for:  klaksvik
# Processing Record 25 of Set 5 | qaqortoq
# Rain KeyError Received for:  qaqortoq
# Snow KeyError Received for:  qaqortoq
# Processing Record 26 of Set 5 | shimoda
# Rain KeyError Received for:  shimoda
# Snow KeyError Received for:  shimoda
# Processing Record 27 of Set 5 | hargeysa
# Rain KeyError Received for:  hargeysa
# Snow KeyError Received for:  hargeysa
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | kaeo
# Rain KeyError Received for:  kaeo
# Snow KeyError Received for:  kaeo
# Processing Record 30 of Set 5 | acapulco
# Rain KeyError Received for:  acapulco
# Snow KeyError Received for:  acapulco
# Processing Record 31 of Set 5 | cabo san lucas
# Rain KeyError Received for:  cabo san lucas
# Snow KeyError Received for:  cabo san lucas
# Processing Record 32 of Set 5 | aksum
# Snow KeyError Received for:  aksum
# Processing Record 33 of Set 5 | kovdor
# Rain KeyError Received for:  kovdor
# Snow KeyError Received for:  kovdor
# Processing Record 34 of Set 5 | evensk
# Rain KeyError Received for:  evensk
# Snow KeyError Received for:  evensk
# Processing Record 35 of Set 5 | aklavik
# Rain KeyError Received for:  aklavik
# Snow KeyError Received for:  aklavik
# Processing Record 36 of Set 5 | aksarka
# Rain KeyError Received for:  aksarka
# Snow KeyError Received for:  aksarka
# Processing Record 37 of Set 5 | qui nhon
# Rain KeyError Received for:  qui nhon
# Snow KeyError Received for:  qui nhon
# Processing Record 38 of Set 5 | quang ngai
# Rain KeyError Received for:  quang ngai
# Snow KeyError Received for:  quang ngai
# Processing Record 39 of Set 5 | sabang
# Rain KeyError Received for:  sabang
# Snow KeyError Received for:  sabang
# Processing Record 40 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 41 of Set 5 | cahuacan
# Rain KeyError Received for:  cahuacan
# Snow KeyError Received for:  cahuacan
# Processing Record 42 of Set 5 | lavrentiya
# Rain KeyError Received for:  lavrentiya
# Snow KeyError Received for:  lavrentiya
# Processing Record 43 of Set 5 | faanui
# Rain KeyError Received for:  faanui
# Snow KeyError Received for:  faanui
# Processing Record 44 of Set 5 | vestmannaeyjar
# Rain KeyError Received for:  vestmannaeyjar
# Snow KeyError Received for:  vestmannaeyjar
# Processing Record 45 of Set 5 | sukhobezvodnoye
# Rain KeyError Received for:  sukhobezvodnoye
# Snow KeyError Received for:  sukhobezvodnoye
# Processing Record 46 of Set 5 | ust-omchug
# Rain KeyError Received for:  ust-omchug
# Snow KeyError Received for:  ust-omchug
# Processing Record 47 of Set 5 | broome
# Rain KeyError Received for:  broome
# Snow KeyError Received for:  broome
# Processing Record 48 of Set 5 | temanggung
# Rain KeyError Received for:  temanggung
# Snow KeyError Received for:  temanggung
# Processing Record 49 of Set 5 | manta
# Rain KeyError Received for:  manta
# Snow KeyError Received for:  manta
# Processing Record 50 of Set 5 | middletown
# Rain KeyError Received for:  middletown
# Snow KeyError Received for:  middletown
# Processing Record 1 of Set 6 | tessalit
# Rain KeyError Received for:  tessalit
# Snow KeyError Received for:  tessalit
# Processing Record 2 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 3 of Set 6 | impfondo
# Snow KeyError Received for:  impfondo
# Processing Record 4 of Set 6 | sassandra
# Rain KeyError Received for:  sassandra
# Snow KeyError Received for:  sassandra
# Processing Record 5 of Set 6 | xiaoshi
# Rain KeyError Received for:  xiaoshi
# Snow KeyError Received for:  xiaoshi
# Processing Record 6 of Set 6 | hami
# Rain KeyError Received for:  hami
# Snow KeyError Received for:  hami
# Processing Record 7 of Set 6 | lorengau
# Rain KeyError Received for:  lorengau
# Snow KeyError Received for:  lorengau
# Processing Record 8 of Set 6 | ambon
# Snow KeyError Received for:  ambon
# Processing Record 9 of Set 6 | kirakira
# Rain KeyError Received for:  kirakira
# Snow KeyError Received for:  kirakira
# Processing Record 10 of Set 6 | leningradskiy
# Rain KeyError Received for:  leningradskiy
# Snow KeyError Received for:  leningradskiy
# Processing Record 11 of Set 6 | san quintin
# Rain KeyError Received for:  san quintin
# Snow KeyError Received for:  san quintin
# Processing Record 12 of Set 6 | makakilo city
# Rain KeyError Received for:  makakilo city
# Snow KeyError Received for:  makakilo city
# Processing Record 13 of Set 6 | cansancao
# Rain KeyError Received for:  cansancao
# Snow KeyError Received for:  cansancao
# Processing Record 14 of Set 6 | vrangel
# Rain KeyError Received for:  vrangel
# Snow KeyError Received for:  vrangel
# Processing Record 15 of Set 6 | barwala
# Snow KeyError Received for:  barwala
# Processing Record 16 of Set 6 | saint anthony
# Rain KeyError Received for:  saint anthony
# Snow KeyError Received for:  saint anthony
# Processing Record 17 of Set 6 | yulara
# Rain KeyError Received for:  yulara
# Snow KeyError Received for:  yulara
# Processing Record 18 of Set 6 | jumla
# Rain KeyError Received for:  jumla
# Snow KeyError Received for:  jumla
# Processing Record 19 of Set 6 | ponta delgada
# Rain KeyError Received for:  ponta delgada
# Snow KeyError Received for:  ponta delgada
# Processing Record 20 of Set 6 | kruisfontein
# Rain KeyError Received for:  kruisfontein
# Snow KeyError Received for:  kruisfontein
# Processing Record 21 of Set 6 | yelovo
# Rain KeyError Received for:  yelovo
# Snow KeyError Received for:  yelovo
# Processing Record 22 of Set 6 | la ronge
# Rain KeyError Received for:  la ronge
# Snow KeyError Received for:  la ronge
# Processing Record 23 of Set 6 | cherbourg
# Rain KeyError Received for:  cherbourg
# Snow KeyError Received for:  cherbourg
# Processing Record 24 of Set 6 | saint-michel-des-saints
# Rain KeyError Received for:  saint-michel-des-saints
# Snow KeyError Received for:  saint-michel-des-saints
# Processing Record 25 of Set 6 | vila franca do campo
# Rain KeyError Received for:  vila franca do campo
# Snow KeyError Received for:  vila franca do campo
# Processing Record 26 of Set 6 | cidreira
# Rain KeyError Received for:  cidreira
# Snow KeyError Received for:  cidreira
# Processing Record 27 of Set 6 | ulladulla
# Rain KeyError Received for:  ulladulla
# Snow KeyError Received for:  ulladulla
# Processing Record 28 of Set 6 | nuuk
# Rain KeyError Received for:  nuuk
# Snow KeyError Received for:  nuuk
# Processing Record 29 of Set 6 | kitui
# Rain KeyError Received for:  kitui
# Snow KeyError Received for:  kitui
# Processing Record 30 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | raudeberg
# Snow KeyError Received for:  raudeberg
# Processing Record 32 of Set 6 | kenai
# Rain KeyError Received for:  kenai
# Snow KeyError Received for:  kenai
# Processing Record 33 of Set 6 | nakhon sawan
# Rain KeyError Received for:  nakhon sawan
# Snow KeyError Received for:  nakhon sawan
# Processing Record 34 of Set 6 | casablanca
# Rain KeyError Received for:  casablanca
# Snow KeyError Received for:  casablanca
# Processing Record 35 of Set 6 | longyearbyen
# Rain KeyError Received for:  longyearbyen
# Snow KeyError Received for:  longyearbyen
# Processing Record 36 of Set 6 | lompoc
# Rain KeyError Received for:  lompoc
# Snow KeyError Received for:  lompoc
# Processing Record 37 of Set 6 | port lincoln
# Rain KeyError Received for:  port lincoln
# Snow KeyError Received for:  port lincoln
# Processing Record 38 of Set 6 | magadan
# Rain KeyError Received for:  magadan
# Snow KeyError Received for:  magadan
# Processing Record 39 of Set 6 | luderitz
# Rain KeyError Received for:  luderitz
# Snow KeyError Received for:  luderitz
# Processing Record 40 of Set 6 | omutinskoye
# City not found. Skipping...
# Processing Record 41 of Set 6 | killybegs
# Rain KeyError Received for:  killybegs
# Snow KeyError Received for:  killybegs
# Processing Record 42 of Set 6 | boma
# Rain KeyError Received for:  boma
# Snow KeyError Received for:  boma
# Processing Record 43 of Set 6 | lazaro cardenas
# Snow KeyError Received for:  lazaro cardenas
# Processing Record 44 of Set 6 | crixas
# Rain KeyError Received for:  crixas
# Snow KeyError Received for:  crixas
# Processing Record 45 of Set 6 | verkhoyansk
# Rain KeyError Received for:  verkhoyansk
# Snow KeyError Received for:  verkhoyansk
# Processing Record 46 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 6 | lebu
# Snow KeyError Received for:  lebu
# Processing Record 48 of Set 6 | jyvaskyla
# Rain KeyError Received for:  jyvaskyla
# Snow KeyError Received for:  jyvaskyla
# Processing Record 49 of Set 6 | souillac
# Rain KeyError Received for:  souillac
# Snow KeyError Received for:  souillac
# Processing Record 50 of Set 6 | liku
# Snow KeyError Received for:  liku
# Processing Record 1 of Set 7 | taltal
# Rain KeyError Received for:  taltal
# Snow KeyError Received for:  taltal
# Processing Record 2 of Set 7 | kutum
# Rain KeyError Received for:  kutum
# Snow KeyError Received for:  kutum
# Processing Record 3 of Set 7 | ostrovnoy
# Rain KeyError Received for:  ostrovnoy
# Snow KeyError Received for:  ostrovnoy
# Processing Record 4 of Set 7 | buala
# Rain KeyError Received for:  buala
# Snow KeyError Received for:  buala
# Processing Record 5 of Set 7 | nikolskoye
# Rain KeyError Received for:  nikolskoye
# Snow KeyError Received for:  nikolskoye
# Processing Record 6 of Set 7 | malakal
# Snow KeyError Received for:  malakal
# Processing Record 7 of Set 7 | oktyabrskoye
# Rain KeyError Received for:  oktyabrskoye
# Snow KeyError Received for:  oktyabrskoye
# Processing Record 8 of Set 7 | chulman
# Rain KeyError Received for:  chulman
# Snow KeyError Received for:  chulman
# Processing Record 9 of Set 7 | mitsamiouli
# Rain KeyError Received for:  mitsamiouli
# Snow KeyError Received for:  mitsamiouli
# Processing Record 10 of Set 7 | itoman
# Rain KeyError Received for:  itoman
# Snow KeyError Received for:  itoman
# Processing Record 11 of Set 7 | khatanga
# Rain KeyError Received for:  khatanga
# Snow KeyError Received for:  khatanga
# Processing Record 12 of Set 7 | corning
# Rain KeyError Received for:  corning
# Snow KeyError Received for:  corning
# Processing Record 13 of Set 7 | roscrea
# Rain KeyError Received for:  roscrea
# Snow KeyError Received for:  roscrea
# Processing Record 14 of Set 7 | lithakia
# Rain KeyError Received for:  lithakia
# Snow KeyError Received for:  lithakia
# Processing Record 15 of Set 7 | manjacaze
# Rain KeyError Received for:  manjacaze
# Snow KeyError Received for:  manjacaze
# Processing Record 16 of Set 7 | cap malheureux
# Rain KeyError Received for:  cap malheureux
# Snow KeyError Received for:  cap malheureux
# Processing Record 17 of Set 7 | college
# Rain KeyError Received for:  college
# Snow KeyError Received for:  college
# Processing Record 18 of Set 7 | husavik
# Rain KeyError Received for:  husavik
# Snow KeyError Received for:  husavik
# Processing Record 19 of Set 7 | mwene-ditu
# Rain KeyError Received for:  mwene-ditu
# Snow KeyError Received for:  mwene-ditu
# Processing Record 20 of Set 7 | kavaratti
# Snow KeyError Received for:  kavaratti
# Processing Record 21 of Set 7 | vila velha
# Rain KeyError Received for:  vila velha
# Snow KeyError Received for:  vila velha
# Processing Record 22 of Set 7 | thinadhoo
# Rain KeyError Received for:  thinadhoo
# Snow KeyError Received for:  thinadhoo
# Processing Record 23 of Set 7 | san rafael
# Rain KeyError Received for:  san rafael
# Snow KeyError Received for:  san rafael
# Processing Record 24 of Set 7 | honningsvag
# Rain KeyError Received for:  honningsvag
# Snow KeyError Received for:  honningsvag
# Processing Record 25 of Set 7 | rio gallegos
# Rain KeyError Received for:  rio gallegos
# Snow KeyError Received for:  rio gallegos
# Processing Record 26 of Set 7 | coeneo
# Rain KeyError Received for:  coeneo
# Snow KeyError Received for:  coeneo
# Processing Record 27 of Set 7 | mehamn
# Rain KeyError Received for:  mehamn
# Snow KeyError Received for:  mehamn
# Processing Record 28 of Set 7 | tuatapere
# Snow KeyError Received for:  tuatapere
# Processing Record 29 of Set 7 | mlonggo
# Rain KeyError Received for:  mlonggo
# Snow KeyError Received for:  mlonggo
# Processing Record 30 of Set 7 | saint-francois
# Rain KeyError Received for:  saint-francois
# Snow KeyError Received for:  saint-francois
# Processing Record 31 of Set 7 | linguere
# Snow KeyError Received for:  linguere
# Processing Record 32 of Set 7 | coquimbo
# Rain KeyError Received for:  coquimbo
# Snow KeyError Received for:  coquimbo
# Processing Record 33 of Set 7 | hithadhoo
# Snow KeyError Received for:  hithadhoo
# Processing Record 34 of Set 7 | trincomalee
# Rain KeyError Received for:  trincomalee
# Snow KeyError Received for:  trincomalee
# Processing Record 35 of Set 7 | atar
# Rain KeyError Received for:  atar
# Snow KeyError Received for:  atar
# Processing Record 36 of Set 7 | iquique
# Rain KeyError Received for:  iquique
# Snow KeyError Received for:  iquique
# Processing Record 37 of Set 7 | gazanjyk
# Rain KeyError Received for:  gazanjyk
# Snow KeyError Received for:  gazanjyk
# Processing Record 38 of Set 7 | prainha
# Rain KeyError Received for:  prainha
# Snow KeyError Received for:  prainha
# Processing Record 39 of Set 7 | ibra
# Rain KeyError Received for:  ibra
# Snow KeyError Received for:  ibra
# Processing Record 40 of Set 7 | baoqing
# Rain KeyError Received for:  baoqing
# Snow KeyError Received for:  baoqing
# Processing Record 41 of Set 7 | aykhal
# Rain KeyError Received for:  aykhal
# Snow KeyError Received for:  aykhal
# Processing Record 42 of Set 7 | savonlinna
# Snow KeyError Received for:  savonlinna
# Processing Record 43 of Set 7 | coahuayana
# Rain KeyError Received for:  coahuayana
# Snow KeyError Received for:  coahuayana
# Processing Record 44 of Set 7 | kurchum
# Rain KeyError Received for:  kurchum
# Snow KeyError Received for:  kurchum
# Processing Record 45 of Set 7 | arica
# Rain KeyError Received for:  arica
# Snow KeyError Received for:  arica
# Processing Record 46 of Set 7 | sechura
# Rain KeyError Received for:  sechura
# Snow KeyError Received for:  sechura
# Processing Record 47 of Set 7 | seymchan
# Rain KeyError Received for:  seymchan
# Snow KeyError Received for:  seymchan
# Processing Record 48 of Set 7 | alice springs
# Rain KeyError Received for:  alice springs
# Snow KeyError Received for:  alice springs
# Processing Record 49 of Set 7 | dingle
# Rain KeyError Received for:  dingle
# Snow KeyError Received for:  dingle
# Processing Record 50 of Set 7 | tiznit
# Rain KeyError Received for:  tiznit
# Snow KeyError Received for:  tiznit
# Processing Record 1 of Set 8 | sao joao da barra
# Rain KeyError Received for:  sao joao da barra
# Snow KeyError Received for:  sao joao da barra
# Processing Record 2 of Set 8 | erenhot
# Rain KeyError Received for:  erenhot
# Snow KeyError Received for:  erenhot
# Processing Record 3 of Set 8 | bafq
# Rain KeyError Received for:  bafq
# Snow KeyError Received for:  bafq
# Processing Record 4 of Set 8 | saint george
# Rain KeyError Received for:  saint george
# Snow KeyError Received for:  saint george
# Processing Record 5 of Set 8 | bossier city
# Rain KeyError Received for:  bossier city
# Snow KeyError Received for:  bossier city
# Processing Record 6 of Set 8 | mani
# Snow KeyError Received for:  mani
# Processing Record 7 of Set 8 | roquetas de mar
# Rain KeyError Received for:  roquetas de mar
# Snow KeyError Received for:  roquetas de mar
# Processing Record 8 of Set 8 | shirhatti
# Rain KeyError Received for:  shirhatti
# Snow KeyError Received for:  shirhatti
# Processing Record 9 of Set 8 | severo-kurilsk
# Snow KeyError Received for:  severo-kurilsk
# Processing Record 10 of Set 8 | larsnes
# Snow KeyError Received for:  larsnes
# Processing Record 11 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 8 | quelimane
# Rain KeyError Received for:  quelimane
# Snow KeyError Received for:  quelimane
# Processing Record 13 of Set 8 | maragogi
# Snow KeyError Received for:  maragogi
# Processing Record 14 of Set 8 | beloha
# Rain KeyError Received for:  beloha
# Snow KeyError Received for:  beloha
# Processing Record 15 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 8 | wattegama
# Rain KeyError Received for:  wattegama
# Snow KeyError Received for:  wattegama
# Processing Record 17 of Set 8 | pevek
# Rain KeyError Received for:  pevek
# Snow KeyError Received for:  pevek
# Processing Record 18 of Set 8 | hays
# Rain KeyError Received for:  hays
# Snow KeyError Received for:  hays
# Processing Record 19 of Set 8 | la rioja
# Snow KeyError Received for:  la rioja
# Processing Record 20 of Set 8 | belmonte
# Rain KeyError Received for:  belmonte
# Snow KeyError Received for:  belmonte
# Processing Record 21 of Set 8 | bubaque
# Snow KeyError Received for:  bubaque
# Processing Record 22 of Set 8 | ipora
# Rain KeyError Received for:  ipora
# Snow KeyError Received for:  ipora
# Processing Record 23 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 8 | piskivka
# Rain KeyError Received for:  piskivka
# Snow KeyError Received for:  piskivka
# Processing Record 25 of Set 8 | kanchanaburi
# Rain KeyError Received for:  kanchanaburi
# Snow KeyError Received for:  kanchanaburi
# Processing Record 26 of Set 8 | isangel
# Rain KeyError Received for:  isangel
# Snow KeyError Received for:  isangel
# Processing Record 27 of Set 8 | oranjestad
# Rain KeyError Received for:  oranjestad
# Snow KeyError Received for:  oranjestad
# Processing Record 28 of Set 8 | pankrushikha
# Rain KeyError Received for:  pankrushikha
# Snow KeyError Received for:  pankrushikha
# Processing Record 29 of Set 8 | galway
# Rain KeyError Received for:  galway
# Snow KeyError Received for:  galway
# Processing Record 30 of Set 8 | sigli
# Rain KeyError Received for:  sigli
# Snow KeyError Received for:  sigli
# Processing Record 31 of Set 8 | skjervoy
# Rain KeyError Received for:  skjervoy
# Snow KeyError Received for:  skjervoy
# Processing Record 32 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 8 | faya
# Rain KeyError Received for:  faya
# Snow KeyError Received for:  faya
# Processing Record 34 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 8 | codrington
# Rain KeyError Received for:  codrington
# Snow KeyError Received for:  codrington
# Processing Record 36 of Set 8 | mountain home
# Rain KeyError Received for:  mountain home
# Snow KeyError Received for:  mountain home
# Processing Record 37 of Set 8 | rio grande
# Rain KeyError Received for:  rio grande
# Snow KeyError Received for:  rio grande
# Processing Record 38 of Set 8 | agnibilekrou
# Rain KeyError Received for:  agnibilekrou
# Snow KeyError Received for:  agnibilekrou
# Processing Record 39 of Set 8 | matamoros
# Rain KeyError Received for:  matamoros
# Snow KeyError Received for:  matamoros
# Processing Record 40 of Set 8 | sao joao nepomuceno
# Rain KeyError Received for:  sao joao nepomuceno
# Snow KeyError Received for:  sao joao nepomuceno
# Processing Record 41 of Set 8 | pimentel
# Rain KeyError Received for:  pimentel
# Snow KeyError Received for:  pimentel
# Processing Record 42 of Set 8 | piacabucu
# Snow KeyError Received for:  piacabucu
# Processing Record 43 of Set 8 | kalmunai
# Rain KeyError Received for:  kalmunai
# Snow KeyError Received for:  kalmunai
# Processing Record 44 of Set 8 | osorio
# Snow KeyError Received for:  osorio
# Processing Record 45 of Set 8 | brownsville
# Rain KeyError Received for:  brownsville
# Snow KeyError Received for:  brownsville
# Processing Record 46 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 48 of Set 8 | norwich
# Rain KeyError Received for:  norwich
# Snow KeyError Received for:  norwich
# Processing Record 49 of Set 8 | yumen
# Rain KeyError Received for:  yumen
# Snow KeyError Received for:  yumen
# Processing Record 50 of Set 8 | aurich
# Rain KeyError Received for:  aurich
# Snow KeyError Received for:  aurich
# Processing Record 1 of Set 9 | sao luis de montes belos
# Rain KeyError Received for:  sao luis de montes belos
# Snow KeyError Received for:  sao luis de montes belos
# Processing Record 2 of Set 9 | verkhnevilyuysk
# Rain KeyError Received for:  verkhnevilyuysk
# Snow KeyError Received for:  verkhnevilyuysk
# Processing Record 3 of Set 9 | maniitsoq
# Rain KeyError Received for:  maniitsoq
# Snow KeyError Received for:  maniitsoq
# Processing Record 4 of Set 9 | tarpon springs
# Rain KeyError Received for:  tarpon springs
# Snow KeyError Received for:  tarpon springs
# Processing Record 5 of Set 9 | vestmanna
# Rain KeyError Received for:  vestmanna
# Snow KeyError Received for:  vestmanna
# Processing Record 6 of Set 9 | wausau
# Rain KeyError Received for:  wausau
# Snow KeyError Received for:  wausau
# Processing Record 7 of Set 9 | wilmington
# Snow KeyError Received for:  wilmington
# Processing Record 8 of Set 9 | kununurra
# Rain KeyError Received for:  kununurra
# Snow KeyError Received for:  kununurra
# Processing Record 9 of Set 9 | oparino
# Rain KeyError Received for:  oparino
# Snow KeyError Received for:  oparino
# Processing Record 10 of Set 9 | fairbanks
# Rain KeyError Received for:  fairbanks
# Snow KeyError Received for:  fairbanks
# Processing Record 11 of Set 9 | dongsheng
# Rain KeyError Received for:  dongsheng
# Snow KeyError Received for:  dongsheng
# Processing Record 12 of Set 9 | namatanai
# Rain KeyError Received for:  namatanai
# Snow KeyError Received for:  namatanai
# Processing Record 13 of Set 9 | klamath falls
# Rain KeyError Received for:  klamath falls
# Snow KeyError Received for:  klamath falls
# Processing Record 14 of Set 9 | coban
# Snow KeyError Received for:  coban
# Processing Record 15 of Set 9 | naze
# Rain KeyError Received for:  naze
# Snow KeyError Received for:  naze
# Processing Record 16 of Set 9 | mazara del vallo
# Rain KeyError Received for:  mazara del vallo
# Snow KeyError Received for:  mazara del vallo
# Processing Record 17 of Set 9 | storforshei
# Rain KeyError Received for:  storforshei
# Snow KeyError Received for:  storforshei
# Processing Record 18 of Set 9 | vanavara
# Rain KeyError Received for:  vanavara
# Snow KeyError Received for:  vanavara
# Processing Record 19 of Set 9 | yar-sale
# Rain KeyError Received for:  yar-sale
# Snow KeyError Received for:  yar-sale
# Processing Record 20 of Set 9 | numaligarh
# Snow KeyError Received for:  numaligarh
# Processing Record 21 of Set 9 | kiruna
# Snow KeyError Received for:  kiruna
# Processing Record 22 of Set 9 | sao gabriel da cachoeira
# Snow KeyError Received for:  sao gabriel da cachoeira
# Processing Record 23 of Set 9 | krasnopavlivka
# Rain KeyError Received for:  krasnopavlivka
# Snow KeyError Received for:  krasnopavlivka
# Processing Record 24 of Set 9 | coihaique
# Rain KeyError Received for:  coihaique
# Snow KeyError Received for:  coihaique
# Processing Record 25 of Set 9 | chama
# Rain KeyError Received for:  chama
# Snow KeyError Received for:  chama
# Processing Record 26 of Set 9 | ketchikan
# Snow KeyError Received for:  ketchikan
# Processing Record 27 of Set 9 | ilhabela
# Rain KeyError Received for:  ilhabela
# Snow KeyError Received for:  ilhabela
# Processing Record 28 of Set 9 | belen
# Rain KeyError Received for:  belen
# Snow KeyError Received for:  belen
# Processing Record 29 of Set 9 | esperance
# Rain KeyError Received for:  esperance
# Snow KeyError Received for:  esperance
# Processing Record 30 of Set 9 | anadyr
# Rain KeyError Received for:  anadyr
# Snow KeyError Received for:  anadyr
# Processing Record 31 of Set 9 | victoria
# Rain KeyError Received for:  victoria
# Snow KeyError Received for:  victoria
# Processing Record 32 of Set 9 | estacion coahuila
# Rain KeyError Received for:  estacion coahuila
# Snow KeyError Received for:  estacion coahuila
# Processing Record 33 of Set 9 | dudinka
# Rain KeyError Received for:  dudinka
# Snow KeyError Received for:  dudinka
# Processing Record 34 of Set 9 | cody
# Rain KeyError Received for:  cody
# Snow KeyError Received for:  cody
# Processing Record 35 of Set 9 | porbandar
# Rain KeyError Received for:  porbandar
# Snow KeyError Received for:  porbandar
# Processing Record 36 of Set 9 | pitimbu
# Rain KeyError Received for:  pitimbu
# Snow KeyError Received for:  pitimbu
# Processing Record 37 of Set 9 | grand gaube
# Rain KeyError Received for:  grand gaube
# Snow KeyError Received for:  grand gaube
# Processing Record 38 of Set 9 | komsomolskiy
# Rain KeyError Received for:  komsomolskiy
# Snow KeyError Received for:  komsomolskiy
# Processing Record 39 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 9 | champerico
# Rain KeyError Received for:  champerico
# Snow KeyError Received for:  champerico
# Processing Record 41 of Set 9 | mabaruma
# Snow KeyError Received for:  mabaruma
# ...
# Rain KeyError Received for:  bongaree
# Snow KeyError Received for:  bongaree
# Processing Record 38 of Set 10 | ardesen
# Rain KeyError Received for:  ardesen
# Snow KeyError Received for:  ardesen
# Processing Record 39 of Set 10 | katsuura
# Rain KeyError Received for:  katsuura
# Snow KeyError Received for:  katsuura
# Processing Record 40 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 10 | salta
# Rain KeyError Received for:  salta
# Snow KeyError Received for:  salta
# Processing Record 42 of Set 10 | rawson
# Rain KeyError Received for:  rawson
# Snow KeyError Received for:  rawson
# Processing Record 43 of Set 10 | simbahan
# Rain KeyError Received for:  simbahan
# Snow KeyError Received for:  simbahan
# Processing Record 44 of Set 10 | chifeng
# Rain KeyError Received for:  chifeng
# Snow KeyError Received for:  chifeng
# Processing Record 45 of Set 10 | margate
# Rain KeyError Received for:  margate
# Snow KeyError Received for:  margate
# Processing Record 46 of Set 10 | dunhua
# Rain KeyError Received for:  dunhua
# Snow KeyError Received for:  dunhua
# Processing Record 47 of Set 10 | arman
# Rain KeyError Received for:  arman
# Snow KeyError Received for:  arman
# Processing Record 48 of Set 10 | port hardy
# Rain KeyError Received for:  port hardy
# Snow KeyError Received for:  port hardy
# Processing Record 49 of Set 10 | bairiki
# Rain KeyError Received for:  bairiki
# Snow KeyError Received for:  bairiki
# Processing Record 50 of Set 10 | remedios
# Rain KeyError Received for:  remedios
# Snow KeyError Received for:  remedios
# Processing Record 1 of Set 11 | natal
# Rain KeyError Received for:  natal
# Snow KeyError Received for:  natal
# Processing Record 2 of Set 11 | kinwat
# Rain KeyError Received for:  kinwat
# Snow KeyError Received for:  kinwat
# Processing Record 3 of Set 11 | copiapo
# Rain KeyError Received for:  copiapo
# Snow KeyError Received for:  copiapo
# Processing Record 4 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 11 | suntar
# Rain KeyError Received for:  suntar
# Snow KeyError Received for:  suntar
# Processing Record 6 of Set 11 | namikupa
# Rain KeyError Received for:  namikupa
# Snow KeyError Received for:  namikupa
# Processing Record 7 of Set 11 | burica
# City not found. Skipping...
# Processing Record 8 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | lethem
# Snow KeyError Received for:  lethem
# Processing Record 10 of Set 11 | nkhotakota
# Rain KeyError Received for:  nkhotakota
# Snow KeyError Received for:  nkhotakota
# Processing Record 11 of Set 11 | zhezkazgan
# Rain KeyError Received for:  zhezkazgan
# Snow KeyError Received for:  zhezkazgan
# Processing Record 12 of Set 11 | tevaitoa
# Rain KeyError Received for:  tevaitoa
# Snow KeyError Received for:  tevaitoa
# Processing Record 13 of Set 11 | sesheke
# Rain KeyError Received for:  sesheke
# Snow KeyError Received for:  sesheke
# Processing Record 14 of Set 11 | kamennomostskoye
# Rain KeyError Received for:  kamennomostskoye
# Snow KeyError Received for:  kamennomostskoye
# Processing Record 15 of Set 11 | elko
# Rain KeyError Received for:  elko
# Snow KeyError Received for:  elko
# Processing Record 16 of Set 11 | eureka
# Rain KeyError Received for:  eureka
# Snow KeyError Received for:  eureka
# Processing Record 17 of Set 11 | havre
# Rain KeyError Received for:  havre
# Snow KeyError Received for:  havre
# Processing Record 18 of Set 11 | peleduy
# Rain KeyError Received for:  peleduy
# Snow KeyError Received for:  peleduy
# Processing Record 19 of Set 11 | coolum beach
# Rain KeyError Received for:  coolum beach
# Snow KeyError Received for:  coolum beach
# Processing Record 20 of Set 11 | veraval
# Snow KeyError Received for:  veraval
# Processing Record 21 of Set 11 | shebalino
# Rain KeyError Received for:  shebalino
# Snow KeyError Received for:  shebalino
# Processing Record 22 of Set 11 | irtyshskiy
# Rain KeyError Received for:  irtyshskiy
# Snow KeyError Received for:  irtyshskiy
# Processing Record 23 of Set 11 | benjamin hill
# Rain KeyError Received for:  benjamin hill
# Snow KeyError Received for:  benjamin hill
# Processing Record 24 of Set 11 | marica
# Rain KeyError Received for:  marica
# Snow KeyError Received for:  marica
# Processing Record 25 of Set 11 | pelhrimov
# Rain KeyError Received for:  pelhrimov
# Snow KeyError Received for:  pelhrimov
# Processing Record 26 of Set 11 | fuling
# Snow KeyError Received for:  fuling
# Processing Record 27 of Set 11 | whitehorse
# Rain KeyError Received for:  whitehorse
# Snow KeyError Received for:  whitehorse
# Processing Record 28 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 11 | lasa
# Rain KeyError Received for:  lasa
# Snow KeyError Received for:  lasa
# Processing Record 30 of Set 11 | nioro
# Snow KeyError Received for:  nioro
# Processing Record 31 of Set 11 | kawalu
# Snow KeyError Received for:  kawalu
# Processing Record 32 of Set 11 | kemijarvi
# Rain KeyError Received for:  kemijarvi
# Snow KeyError Received for:  kemijarvi
# Processing Record 33 of Set 11 | maarianhamina
# Rain KeyError Received for:  maarianhamina
# Snow KeyError Received for:  maarianhamina
# Processing Record 34 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 11 | bathsheba
# Rain KeyError Received for:  bathsheba
# Snow KeyError Received for:  bathsheba
# Processing Record 36 of Set 11 | bandarbeyla
# Rain KeyError Received for:  bandarbeyla
# Snow KeyError Received for:  bandarbeyla
# Processing Record 37 of Set 11 | itapuranga
# Rain KeyError Received for:  itapuranga
# Snow KeyError Received for:  itapuranga
# Processing Record 38 of Set 11 | billings
# Rain KeyError Received for:  billings
# Snow KeyError Received for:  billings
# Processing Record 39 of Set 11 | jiujiang
# Rain KeyError Received for:  jiujiang
# Snow KeyError Received for:  jiujiang
# Processing Record 40 of Set 11 | abashiri
# Rain KeyError Received for:  abashiri
# Snow KeyError Received for:  abashiri
# Processing Record 41 of Set 11 | ballina
# Rain KeyError Received for:  ballina
# Snow KeyError Received for:  ballina
# Processing Record 42 of Set 11 | praia da vitoria
# Rain KeyError Received for:  praia da vitoria
# Snow KeyError Received for:  praia da vitoria
# Processing Record 43 of Set 11 | monrovia
# Rain KeyError Received for:  monrovia
# Snow KeyError Received for:  monrovia
# Processing Record 44 of Set 11 | cairns
# Rain KeyError Received for:  cairns
# Snow KeyError Received for:  cairns
# Processing Record 45 of Set 11 | bosaso
# Rain KeyError Received for:  bosaso
# Snow KeyError Received for:  bosaso
# Processing Record 46 of Set 11 | portree
# Rain KeyError Received for:  portree
# Snow KeyError Received for:  portree
# Processing Record 47 of Set 11 | bowmore
# Rain KeyError Received for:  bowmore
# Snow KeyError Received for:  bowmore
# Processing Record 48 of Set 11 | gilgit
# Snow KeyError Received for:  gilgit
# Processing Record 49 of Set 11 | torbat-e jam
# Rain KeyError Received for:  torbat-e jam
# Snow KeyError Received for:  torbat-e jam
# Processing Record 50 of Set 11 | eldorado
# Rain KeyError Received for:  eldorado
# Snow KeyError Received for:  eldorado
# Processing Record 1 of Set 12 | beisfjord
# Rain KeyError Received for:  beisfjord
# Snow KeyError Received for:  beisfjord
# Processing Record 2 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | padang
# Rain KeyError Received for:  padang
# Snow KeyError Received for:  padang
# Processing Record 4 of Set 12 | kuytun
# Rain KeyError Received for:  kuytun
# Snow KeyError Received for:  kuytun
# Processing Record 5 of Set 12 | haarlemmermeer
# Rain KeyError Received for:  haarlemmermeer
# Snow KeyError Received for:  haarlemmermeer
# Processing Record 6 of Set 12 | poya
# Rain KeyError Received for:  poya
# Snow KeyError Received for:  poya
# Processing Record 7 of Set 12 | desna
# Rain KeyError Received for:  desna
# Snow KeyError Received for:  desna
# Processing Record 8 of Set 12 | samarai
# Snow KeyError Received for:  samarai
# Processing Record 9 of Set 12 | mount isa
# Rain KeyError Received for:  mount isa
# Snow KeyError Received for:  mount isa
# Processing Record 10 of Set 12 | auki
# Rain KeyError Received for:  auki
# Snow KeyError Received for:  auki
# Processing Record 11 of Set 12 | yanam
# Snow KeyError Received for:  yanam
# Processing Record 12 of Set 12 | pisz
# Rain KeyError Received for:  pisz
# Snow KeyError Received for:  pisz
# Processing Record 13 of Set 12 | conselheiro pena
# Rain KeyError Received for:  conselheiro pena
# Snow KeyError Received for:  conselheiro pena
# Processing Record 14 of Set 12 | najran
# Rain KeyError Received for:  najran
# Snow KeyError Received for:  najran
# Processing Record 15 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 12 | gamba
# Rain KeyError Received for:  gamba
# Snow KeyError Received for:  gamba
# Processing Record 17 of Set 12 | calabozo
# Snow KeyError Received for:  calabozo
# Processing Record 18 of Set 12 | port blair
# Rain KeyError Received for:  port blair
# Snow KeyError Received for:  port blair
# Processing Record 19 of Set 12 | grindavik
# Rain KeyError Received for:  grindavik
# Snow KeyError Received for:  grindavik
# Processing Record 20 of Set 12 | samagaltay
# Snow KeyError Received for:  samagaltay
# Processing Record 21 of Set 12 | lengshuijiang
# Rain KeyError Received for:  lengshuijiang
# Snow KeyError Received for:  lengshuijiang
# Processing Record 22 of Set 12 | sisimiut
# Rain KeyError Received for:  sisimiut
# Snow KeyError Received for:  sisimiut
# Processing Record 23 of Set 12 | maningrida
# Rain KeyError Received for:  maningrida
# Snow KeyError Received for:  maningrida
# Processing Record 24 of Set 12 | marawi
# Rain KeyError Received for:  marawi
# Snow KeyError Received for:  marawi
# Processing Record 25 of Set 12 | grimsby
# Rain KeyError Received for:  grimsby
# Snow KeyError Received for:  grimsby
# Processing Record 26 of Set 12 | kathmandu
# Rain KeyError Received for:  kathmandu
# Snow KeyError Received for:  kathmandu
# Processing Record 27 of Set 12 | lachhmangarh
# Snow KeyError Received for:  lachhmangarh
# Processing Record 28 of Set 12 | kushima
# Rain KeyError Received for:  kushima
# Snow KeyError Received for:  kushima
# Processing Record 29 of Set 12 | kjollefjord
# Rain KeyError Received for:  kjollefjord
# Snow KeyError Received for:  kjollefjord
# Processing Record 30 of Set 12 | redding
# Rain KeyError Received for:  redding
# Snow KeyError Received for:  redding
# Processing Record 31 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 12 | isnos
# Snow KeyError Received for:  isnos
# Processing Record 33 of Set 12 | puro
# Rain KeyError Received for:  puro
# Snow KeyError Received for:  puro
# Processing Record 34 of Set 12 | venustiano carranza
# Rain KeyError Received for:  venustiano carranza
# Snow KeyError Received for:  venustiano carranza
# Processing Record 35 of Set 12 | honolulu
# Rain KeyError Received for:  honolulu
# Snow KeyError Received for:  honolulu
# Processing Record 36 of Set 12 | ginda
# Snow KeyError Received for:  ginda
# Processing Record 37 of Set 12 | knysna
# Rain KeyError Received for:  knysna
# Snow KeyError Received for:  knysna
# Processing Record 38 of Set 12 | henties bay
# Rain KeyError Received for:  henties bay
# Snow KeyError Received for:  henties bay
# Processing Record 39 of Set 12 | poum
# Rain KeyError Received for:  poum
# Snow KeyError Received for:  poum
# Processing Record 40 of Set 12 | pacifica
# Rain KeyError Received for:  pacifica
# Snow KeyError Received for:  pacifica
# Processing Record 41 of Set 12 | balabac
# Rain KeyError Received for:  balabac
# Snow KeyError Received for:  balabac
# Processing Record 42 of Set 12 | mana
# Rain KeyError Received for:  mana
# Snow KeyError Received for:  mana
# Processing Record 43 of Set 12 | los llanos de aridane
# Rain KeyError Received for:  los llanos de aridane
# Snow KeyError Received for:  los llanos de aridane
# Processing Record 44 of Set 12 | olinda
# Rain KeyError Received for:  olinda
# Snow KeyError Received for:  olinda
# Processing Record 45 of Set 12 | bambanglipuro
# Snow KeyError Received for:  bambanglipuro
# Processing Record 46 of Set 12 | ishigaki
# Rain KeyError Received for:  ishigaki
# Snow KeyError Received for:  ishigaki
# Processing Record 47 of Set 12 | kajaani
# Rain KeyError Received for:  kajaani
# Snow KeyError Received for:  kajaani
# Processing Record 48 of Set 12 | kieta
# Rain KeyError Received for:  kieta
# Snow KeyError Received for:  kieta
# Processing Record 49 of Set 12 | dubuque
# Rain KeyError Received for:  dubuque
# Snow KeyError Received for:  dubuque
# Processing Record 50 of Set 12 | birao
# Rain KeyError Received for:  birao
# Snow KeyError Received for:  birao
# Processing Record 1 of Set 13 | namtsy
# Rain KeyError Received for:  namtsy
# Snow KeyError Received for:  namtsy
# Processing Record 2 of Set 13 | povenets
# Rain KeyError Received for:  povenets
# Snow KeyError Received for:  povenets
# Processing Record 3 of Set 13 | buchanan
# Rain KeyError Received for:  buchanan
# Snow KeyError Received for:  buchanan
# Processing Record 4 of Set 13 | bintulu
# Rain KeyError Received for:  bintulu
# Snow KeyError Received for:  bintulu
# Processing Record 5 of Set 13 | igunga
# Rain KeyError Received for:  igunga
# Snow KeyError Received for:  igunga
# Processing Record 6 of Set 13 | abay
# Rain KeyError Received for:  abay
# Snow KeyError Received for:  abay
# Processing Record 7 of Set 13 | lata
# Snow KeyError Received for:  lata
# Processing Record 8 of Set 13 | san jeronimo
# Snow KeyError Received for:  san jeronimo
# Processing Record 9 of Set 13 | bilibino
# Snow KeyError Received for:  bilibino
# Processing Record 10 of Set 13 | bulgan
# Rain KeyError Received for:  bulgan
# Snow KeyError Received for:  bulgan
# Processing Record 11 of Set 13 | rawatsar
# Snow KeyError Received for:  rawatsar
# Processing Record 12 of Set 13 | acajutla
# Snow KeyError Received for:  acajutla
# Processing Record 13 of Set 13 | shizunai
# Rain KeyError Received for:  shizunai
# Snow KeyError Received for:  shizunai
# Processing Record 14 of Set 13 | winchester
# Rain KeyError Received for:  winchester
# Snow KeyError Received for:  winchester
# Processing Record 15 of Set 13 | zhigansk
# Rain KeyError Received for:  zhigansk
# Snow KeyError Received for:  zhigansk
# Processing Record 16 of Set 13 | misratah
# Rain KeyError Received for:  misratah
# Snow KeyError Received for:  misratah
# Processing Record 17 of Set 13 | bonoua
# Rain KeyError Received for:  bonoua
# Snow KeyError Received for:  bonoua
# Processing Record 18 of Set 13 | homagama
# Rain KeyError Received for:  homagama
# Snow KeyError Received for:  homagama
# Processing Record 19 of Set 13 | romny
# Rain KeyError Received for:  romny
# Snow KeyError Received for:  romny
# Processing Record 20 of Set 13 | mildura
# Rain KeyError Received for:  mildura
# Snow KeyError Received for:  mildura
# Processing Record 21 of Set 13 | saint-louis
# Rain KeyError Received for:  saint-louis
# Snow KeyError Received for:  saint-louis
# Processing Record 22 of Set 13 | srednekolymsk
# Rain KeyError Received for:  srednekolymsk
# Snow KeyError Received for:  srednekolymsk
# Processing Record 23 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 24 of Set 13 | sibolga
# Rain KeyError Received for:  sibolga
# Snow KeyError Received for:  sibolga
# Processing Record 25 of Set 13 | sao paulo de olivenca
# Snow KeyError Received for:  sao paulo de olivenca
# Processing Record 26 of Set 13 | omboue
# Rain KeyError Received for:  omboue
# Snow KeyError Received for:  omboue
# Processing Record 27 of Set 13 | mugla
# Rain KeyError Received for:  mugla
# Snow KeyError Received for:  mugla
# Processing Record 28 of Set 13 | bilma
# Rain KeyError Received for:  bilma
# Snow KeyError Received for:  bilma
# Processing Record 29 of Set 13 | rincon
# Rain KeyError Received for:  rincon
# Snow KeyError Received for:  rincon
# Processing Record 30 of Set 13 | grimshaw
# Rain KeyError Received for:  grimshaw
# Snow KeyError Received for:  grimshaw
# Processing Record 31 of Set 13 | la asuncion
# Rain KeyError Received for:  la asuncion
# Snow KeyError Received for:  la asuncion
# Processing Record 32 of Set 13 | yokadouma
# Snow KeyError Received for:  yokadouma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Determine length of city_data.  Needs to be over 500
len(city_data)
# Out:
# 580

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Bluff -46.60  168.33     49.64        76          99       19.82
# 1           Atuona  -9.80 -139.03     79.41        78          40       16.96
# 2          Pathein  16.78   94.73     80.08        86          66        3.87
# 3         Smithers  54.78 -127.17     59.00        58          90       11.41
# 4         Pochutla  15.74  -96.47     87.01        62          40       11.41
# 5          Sakakah  29.97   40.21     91.40        18           0       10.29
# 6          Sarkand  45.41   79.92     57.47        74          14        2.64
# 7          Kahului  20.89 -156.47     89.60        40          20       24.16
# 8  Arraial Do Cabo -22.97  -42.03     75.20        69           0       13.87
# 9        Mahebourg -20.41   57.70     69.80        73          40       17.22
#
#            Current Description  Rain (inches)  Snow (inches) Country  \
# 0                   light rain           0.74              0      NZ
# 1                   light rain           0.23              0      PF
# 2                   light rain           0.17              0      MM
# 3              overcast clouds           0.00              0      CA
# 4             scattered clouds           0.00              0      MX
# 5                    clear sky           0.00              0      SA
# 6                   light rain           0.35              0      KZ
# 7                   few clouds           0.00              0      US
# 8                    clear sky           0.00              0      BR
# 9  light intensity shower rain           0.00              0      MU
#
#                   Date
# 0  2020-07-11 21:58:23
# 1  2020-07-11 21:58:23
# 2  2020-07-11 21:58:23
# 3  2020-07-11 21:58:23
# 4  2020-07-11 21:58:24
# 5  2020-07-11 21:57:45
# 6  2020-07-11 21:58:24
# 7  2020-07-11 21:54:58
# 8  2020-07-11 21:58:24
# 9  2020-07-11 21:58:25

# %%
# Reorder columns for asthetics
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description', 'Rain (inches)', 'Snow (inches)']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.60  168.33     49.64        76          99
# 1           Atuona      PF  -9.80 -139.03     79.41        78          40
# 2          Pathein      MM  16.78   94.73     80.08        86          66
# 3         Smithers      CA  54.78 -127.17     59.00        58          90
# 4         Pochutla      MX  15.74  -96.47     87.01        62          40
# 5          Sakakah      SA  29.97   40.21     91.40        18           0
# 6          Sarkand      KZ  45.41   79.92     57.47        74          14
# 7          Kahului      US  20.89 -156.47     89.60        40          20
# 8  Arraial Do Cabo      BR -22.97  -42.03     75.20        69           0
# 9        Mahebourg      MU -20.41   57.70     69.80        73          40
#
#    Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 0       19.82                   light rain           0.74              0
# 1       16.96                   light rain           0.23              0
# 2        3.87                   light rain           0.17              0
# 3       11.41              overcast clouds           0.00              0
# 4       11.41             scattered clouds           0.00              0
# 5       10.29                    clear sky           0.00              0
# 6        2.64                   light rain           0.35              0
# 7       24.16                   few clouds           0.00              0
# 8       13.87                    clear sky           0.00              0
# 9       17.22  light intensity shower rain           0.00              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
