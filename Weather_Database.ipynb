# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key from config.py file.
from config import weather_api_key
# Import the time module.
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Import gmaps module
#import gmaps
# Import the API key.
#from config import g_key

# %%
# Configure gmaps to use your Google API key. You only have to do this once
#gmaps.configure(api_key=g_key)

# %%
##############################
# Part 1: Module 6 Challenge #
##############################

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations. Use zip() to pair them.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates= list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Create an empty list to hold the weather data.
city_data = []
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # % is modulo: the remainder from the division of the first argument to the second
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
   
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descr = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
            print('Rain KeyError Received for: ', city)
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:
            city_snow = 0
            print('Snow KeyError Received for: ', city)
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descr,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sosnovo-ozerskoye
# Rain KeyError Received for:  sosnovo-ozerskoye
# Snow KeyError Received for:  sosnovo-ozerskoye
# Processing Record 2 of Set 1 | kapaa
# Rain KeyError Received for:  kapaa
# Snow KeyError Received for:  kapaa
# Processing Record 3 of Set 1 | mahebourg
# Rain KeyError Received for:  mahebourg
# Snow KeyError Received for:  mahebourg
# Processing Record 4 of Set 1 | cape town
# Snow KeyError Received for:  cape town
# Processing Record 5 of Set 1 | qaanaaq
# Rain KeyError Received for:  qaanaaq
# Snow KeyError Received for:  qaanaaq
# Processing Record 6 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 1 | mazatlan
# Rain KeyError Received for:  mazatlan
# Snow KeyError Received for:  mazatlan
# Processing Record 8 of Set 1 | liverpool
# Rain KeyError Received for:  liverpool
# Snow KeyError Received for:  liverpool
# Processing Record 9 of Set 1 | rikitea
# Rain KeyError Received for:  rikitea
# Snow KeyError Received for:  rikitea
# Processing Record 10 of Set 1 | bredasdorp
# Rain KeyError Received for:  bredasdorp
# Snow KeyError Received for:  bredasdorp
# Processing Record 11 of Set 1 | ushuaia
# Rain KeyError Received for:  ushuaia
# Snow KeyError Received for:  ushuaia
# Processing Record 12 of Set 1 | victoria
# Rain KeyError Received for:  victoria
# Snow KeyError Received for:  victoria
# Processing Record 13 of Set 1 | mataura
# Snow KeyError Received for:  mataura
# Processing Record 14 of Set 1 | barrow
# Rain KeyError Received for:  barrow
# Snow KeyError Received for:  barrow
# Processing Record 15 of Set 1 | albany
# Snow KeyError Received for:  albany
# Processing Record 16 of Set 1 | vaini
# Rain KeyError Received for:  vaini
# Snow KeyError Received for:  vaini
# Processing Record 17 of Set 1 | punta arenas
# Rain KeyError Received for:  punta arenas
# Snow KeyError Received for:  punta arenas
# Processing Record 18 of Set 1 | busselton
# Rain KeyError Received for:  busselton
# Snow KeyError Received for:  busselton
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | fortuna
# Rain KeyError Received for:  fortuna
# Snow KeyError Received for:  fortuna
# Processing Record 21 of Set 1 | dikson
# Rain KeyError Received for:  dikson
# Snow KeyError Received for:  dikson
# Processing Record 22 of Set 1 | kununurra
# Rain KeyError Received for:  kununurra
# Snow KeyError Received for:  kununurra
# Processing Record 23 of Set 1 | hobart
# Rain KeyError Received for:  hobart
# Snow KeyError Received for:  hobart
# Processing Record 24 of Set 1 | roma
# Rain KeyError Received for:  roma
# Snow KeyError Received for:  roma
# Processing Record 25 of Set 1 | henties bay
# Rain KeyError Received for:  henties bay
# Snow KeyError Received for:  henties bay
# Processing Record 26 of Set 1 | pilar
# Rain KeyError Received for:  pilar
# Snow KeyError Received for:  pilar
# Processing Record 27 of Set 1 | coihueco
# Rain KeyError Received for:  coihueco
# Snow KeyError Received for:  coihueco
# Processing Record 28 of Set 1 | konongo
# Snow KeyError Received for:  konongo
# Processing Record 29 of Set 1 | utica
# Rain KeyError Received for:  utica
# Snow KeyError Received for:  utica
# Processing Record 30 of Set 1 | hirara
# Rain KeyError Received for:  hirara
# Snow KeyError Received for:  hirara
# Processing Record 31 of Set 1 | mar del plata
# Rain KeyError Received for:  mar del plata
# Snow KeyError Received for:  mar del plata
# Processing Record 32 of Set 1 | ojinaga
# Rain KeyError Received for:  ojinaga
# Snow KeyError Received for:  ojinaga
# Processing Record 33 of Set 1 | souillac
# Rain KeyError Received for:  souillac
# Snow KeyError Received for:  souillac
# Processing Record 34 of Set 1 | dingle
# Rain KeyError Received for:  dingle
# Snow KeyError Received for:  dingle
# Processing Record 35 of Set 1 | aklavik
# Rain KeyError Received for:  aklavik
# Snow KeyError Received for:  aklavik
# Processing Record 36 of Set 1 | pevek
# Rain KeyError Received for:  pevek
# Snow KeyError Received for:  pevek
# Processing Record 37 of Set 1 | vestmannaeyjar
# Rain KeyError Received for:  vestmannaeyjar
# Snow KeyError Received for:  vestmannaeyjar
# Processing Record 38 of Set 1 | saskylakh
# Snow KeyError Received for:  saskylakh
# Processing Record 39 of Set 1 | prince rupert
# Rain KeyError Received for:  prince rupert
# Snow KeyError Received for:  prince rupert
# Processing Record 40 of Set 1 | provideniya
# Rain KeyError Received for:  provideniya
# Snow KeyError Received for:  provideniya
# Processing Record 41 of Set 1 | asyut
# Rain KeyError Received for:  asyut
# Snow KeyError Received for:  asyut
# Processing Record 42 of Set 1 | fort myers beach
# Rain KeyError Received for:  fort myers beach
# Snow KeyError Received for:  fort myers beach
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 1 | pyay
# Rain KeyError Received for:  pyay
# Snow KeyError Received for:  pyay
# Processing Record 46 of Set 1 | bengkulu
# Rain KeyError Received for:  bengkulu
# Snow KeyError Received for:  bengkulu
# Processing Record 47 of Set 1 | merauke
# Snow KeyError Received for:  merauke
# Processing Record 48 of Set 1 | abnub
# Rain KeyError Received for:  abnub
# Snow KeyError Received for:  abnub
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | maebaru
# Rain KeyError Received for:  maebaru
# Snow KeyError Received for:  maebaru
# Processing Record 2 of Set 2 | alofi
# Rain KeyError Received for:  alofi
# Snow KeyError Received for:  alofi
# Processing Record 3 of Set 2 | mount gambier
# Rain KeyError Received for:  mount gambier
# Snow KeyError Received for:  mount gambier
# Processing Record 4 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | lata
# Rain KeyError Received for:  lata
# Snow KeyError Received for:  lata
# Processing Record 6 of Set 2 | ribeira grande
# Rain KeyError Received for:  ribeira grande
# Snow KeyError Received for:  ribeira grande
# Processing Record 7 of Set 2 | beyneu
# Rain KeyError Received for:  beyneu
# Snow KeyError Received for:  beyneu
# Processing Record 8 of Set 2 | nikolskoye
# Rain KeyError Received for:  nikolskoye
# Snow KeyError Received for:  nikolskoye
# Processing Record 9 of Set 2 | maceio
# Rain KeyError Received for:  maceio
# Snow KeyError Received for:  maceio
# Processing Record 10 of Set 2 | solano
# Rain KeyError Received for:  solano
# Snow KeyError Received for:  solano
# Processing Record 11 of Set 2 | kaitangata
# Rain KeyError Received for:  kaitangata
# Snow KeyError Received for:  kaitangata
# Processing Record 12 of Set 2 | tuatapere
# Rain KeyError Received for:  tuatapere
# Snow KeyError Received for:  tuatapere
# Processing Record 13 of Set 2 | gimli
# Rain KeyError Received for:  gimli
# Snow KeyError Received for:  gimli
# Processing Record 14 of Set 2 | saint-augustin
# Rain KeyError Received for:  saint-augustin
# Snow KeyError Received for:  saint-augustin
# Processing Record 15 of Set 2 | mehamn
# Rain KeyError Received for:  mehamn
# Snow KeyError Received for:  mehamn
# Processing Record 16 of Set 2 | namibe
# Rain KeyError Received for:  namibe
# Snow KeyError Received for:  namibe
# Processing Record 17 of Set 2 | flinders
# Snow KeyError Received for:  flinders
# Processing Record 18 of Set 2 | cabo san lucas
# Rain KeyError Received for:  cabo san lucas
# Snow KeyError Received for:  cabo san lucas
# Processing Record 19 of Set 2 | lengshuijiang
# Snow KeyError Received for:  lengshuijiang
# Processing Record 20 of Set 2 | akdepe
# Rain KeyError Received for:  akdepe
# Snow KeyError Received for:  akdepe
# Processing Record 21 of Set 2 | roura
# Snow KeyError Received for:  roura
# Processing Record 22 of Set 2 | lebu
# Rain KeyError Received for:  lebu
# Snow KeyError Received for:  lebu
# Processing Record 23 of Set 2 | bagdarin
# Rain KeyError Received for:  bagdarin
# Snow KeyError Received for:  bagdarin
# Processing Record 24 of Set 2 | hermanus
# Snow KeyError Received for:  hermanus
# Processing Record 25 of Set 2 | kirchhain
# Rain KeyError Received for:  kirchhain
# Snow KeyError Received for:  kirchhain
# Processing Record 26 of Set 2 | nyurba
# Rain KeyError Received for:  nyurba
# Snow KeyError Received for:  nyurba
# Processing Record 27 of Set 2 | hofn
# Rain KeyError Received for:  hofn
# Snow KeyError Received for:  hofn
# Processing Record 28 of Set 2 | makakilo city
# Rain KeyError Received for:  makakilo city
# Snow KeyError Received for:  makakilo city
# Processing Record 29 of Set 2 | longyearbyen
# Rain KeyError Received for:  longyearbyen
# Snow KeyError Received for:  longyearbyen
# Processing Record 30 of Set 2 | richards bay
# Rain KeyError Received for:  richards bay
# Snow KeyError Received for:  richards bay
# Processing Record 31 of Set 2 | port alfred
# Rain KeyError Received for:  port alfred
# Snow KeyError Received for:  port alfred
# Processing Record 32 of Set 2 | hambantota
# Rain KeyError Received for:  hambantota
# Snow KeyError Received for:  hambantota
# Processing Record 33 of Set 2 | damghan
# Rain KeyError Received for:  damghan
# Snow KeyError Received for:  damghan
# Processing Record 34 of Set 2 | gat
# Rain KeyError Received for:  gat
# Snow KeyError Received for:  gat
# Processing Record 35 of Set 2 | bluff
# Snow KeyError Received for:  bluff
# Processing Record 36 of Set 2 | necochea
# Rain KeyError Received for:  necochea
# Snow KeyError Received for:  necochea
# Processing Record 37 of Set 2 | puerto ayora
# Rain KeyError Received for:  puerto ayora
# Snow KeyError Received for:  puerto ayora
# Processing Record 38 of Set 2 | changji
# Rain KeyError Received for:  changji
# Snow KeyError Received for:  changji
# Processing Record 39 of Set 2 | tilichiki
# Rain KeyError Received for:  tilichiki
# Snow KeyError Received for:  tilichiki
# Processing Record 40 of Set 2 | unye
# City not found. Skipping...
# Processing Record 41 of Set 2 | guerrero negro
# Rain KeyError Received for:  guerrero negro
# Snow KeyError Received for:  guerrero negro
# Processing Record 42 of Set 2 | port elizabeth
# Rain KeyError Received for:  port elizabeth
# Snow KeyError Received for:  port elizabeth
# Processing Record 43 of Set 2 | shangzhi
# Rain KeyError Received for:  shangzhi
# Snow KeyError Received for:  shangzhi
# Processing Record 44 of Set 2 | capul
# Rain KeyError Received for:  capul
# Snow KeyError Received for:  capul
# Processing Record 45 of Set 2 | ambilobe
# Rain KeyError Received for:  ambilobe
# Snow KeyError Received for:  ambilobe
# Processing Record 46 of Set 2 | la ronge
# Rain KeyError Received for:  la ronge
# Snow KeyError Received for:  la ronge
# Processing Record 47 of Set 2 | cherskiy
# Rain KeyError Received for:  cherskiy
# Snow KeyError Received for:  cherskiy
# Processing Record 48 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 2 | arraial do cabo
# Rain KeyError Received for:  arraial do cabo
# Snow KeyError Received for:  arraial do cabo
# Processing Record 50 of Set 2 | san quintin
# Rain KeyError Received for:  san quintin
# Snow KeyError Received for:  san quintin
# Processing Record 1 of Set 3 | arys
# Rain KeyError Received for:  arys
# Snow KeyError Received for:  arys
# Processing Record 2 of Set 3 | airai
# Rain KeyError Received for:  airai
# Snow KeyError Received for:  airai
# Processing Record 3 of Set 3 | lobatse
# Rain KeyError Received for:  lobatse
# Snow KeyError Received for:  lobatse
# Processing Record 4 of Set 3 | manono
# Rain KeyError Received for:  manono
# Snow KeyError Received for:  manono
# Processing Record 5 of Set 3 | torbay
# Rain KeyError Received for:  torbay
# Snow KeyError Received for:  torbay
# Processing Record 6 of Set 3 | arklow
# Rain KeyError Received for:  arklow
# Snow KeyError Received for:  arklow
# Processing Record 7 of Set 3 | barroquinha
# Rain KeyError Received for:  barroquinha
# Snow KeyError Received for:  barroquinha
# Processing Record 8 of Set 3 | petrozavodsk
# Rain KeyError Received for:  petrozavodsk
# Snow KeyError Received for:  petrozavodsk
# Processing Record 9 of Set 3 | port-gentil
# Rain KeyError Received for:  port-gentil
# Snow KeyError Received for:  port-gentil
# Processing Record 10 of Set 3 | avarua
# Rain KeyError Received for:  avarua
# Snow KeyError Received for:  avarua
# Processing Record 11 of Set 3 | deputatskiy
# Rain KeyError Received for:  deputatskiy
# Snow KeyError Received for:  deputatskiy
# Processing Record 12 of Set 3 | manokwari
# Rain KeyError Received for:  manokwari
# Snow KeyError Received for:  manokwari
# Processing Record 13 of Set 3 | ahipara
# Rain KeyError Received for:  ahipara
# Snow KeyError Received for:  ahipara
# Processing Record 14 of Set 3 | chokurdakh
# Rain KeyError Received for:  chokurdakh
# Snow KeyError Received for:  chokurdakh
# Processing Record 15 of Set 3 | berlevag
# Rain KeyError Received for:  berlevag
# Snow KeyError Received for:  berlevag
# Processing Record 16 of Set 3 | golden
# Rain KeyError Received for:  golden
# Snow KeyError Received for:  golden
# Processing Record 17 of Set 3 | butaritari
# Snow KeyError Received for:  butaritari
# Processing Record 18 of Set 3 | coquimbo
# Rain KeyError Received for:  coquimbo
# Snow KeyError Received for:  coquimbo
# Processing Record 19 of Set 3 | padang
# Snow KeyError Received for:  padang
# Processing Record 20 of Set 3 | atuona
# Snow KeyError Received for:  atuona
# Processing Record 21 of Set 3 | nieuw amsterdam
# Rain KeyError Received for:  nieuw amsterdam
# Snow KeyError Received for:  nieuw amsterdam
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | grindavik
# Rain KeyError Received for:  grindavik
# Snow KeyError Received for:  grindavik
# Processing Record 24 of Set 3 | carnarvon
# Rain KeyError Received for:  carnarvon
# Snow KeyError Received for:  carnarvon
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | chitose
# Rain KeyError Received for:  chitose
# Snow KeyError Received for:  chitose
# Processing Record 27 of Set 3 | hithadhoo
# Rain KeyError Received for:  hithadhoo
# Snow KeyError Received for:  hithadhoo
# Processing Record 28 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 29 of Set 3 | sitka
# Snow KeyError Received for:  sitka
# Processing Record 30 of Set 3 | savalou
# Rain KeyError Received for:  savalou
# Snow KeyError Received for:  savalou
# Processing Record 31 of Set 3 | coruripe
# Rain KeyError Received for:  coruripe
# Snow KeyError Received for:  coruripe
# Processing Record 32 of Set 3 | dudinka
# Rain KeyError Received for:  dudinka
# Snow KeyError Received for:  dudinka
# Processing Record 33 of Set 3 | grenaa
# Rain KeyError Received for:  grenaa
# Snow KeyError Received for:  grenaa
# Processing Record 34 of Set 3 | coihaique
# Rain KeyError Received for:  coihaique
# Snow KeyError Received for:  coihaique
# Processing Record 35 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | ponta do sol
# Rain KeyError Received for:  ponta do sol
# Snow KeyError Received for:  ponta do sol
# Processing Record 38 of Set 3 | vanderhoof
# Rain KeyError Received for:  vanderhoof
# Snow KeyError Received for:  vanderhoof
# Processing Record 39 of Set 3 | vestmanna
# Rain KeyError Received for:  vestmanna
# Snow KeyError Received for:  vestmanna
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | alice springs
# Rain KeyError Received for:  alice springs
# Snow KeyError Received for:  alice springs
# Processing Record 42 of Set 3 | kozhva
# Snow KeyError Received for:  kozhva
# Processing Record 43 of Set 3 | sayyan
# Rain KeyError Received for:  sayyan
# Snow KeyError Received for:  sayyan
# Processing Record 44 of Set 3 | mazagao
# Rain KeyError Received for:  mazagao
# Snow KeyError Received for:  mazagao
# Processing Record 45 of Set 3 | los llanos de aridane
# Rain KeyError Received for:  los llanos de aridane
# Snow KeyError Received for:  los llanos de aridane
# Processing Record 46 of Set 3 | moindou
# Rain KeyError Received for:  moindou
# Snow KeyError Received for:  moindou
# Processing Record 47 of Set 3 | lukaya
# Rain KeyError Received for:  lukaya
# Snow KeyError Received for:  lukaya
# Processing Record 48 of Set 3 | clyde river
# Rain KeyError Received for:  clyde river
# Snow KeyError Received for:  clyde river
# Processing Record 49 of Set 3 | taoudenni
# Rain KeyError Received for:  taoudenni
# Snow KeyError Received for:  taoudenni
# Processing Record 50 of Set 3 | castro
# Rain KeyError Received for:  castro
# Snow KeyError Received for:  castro
# Processing Record 1 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | jamestown
# Rain KeyError Received for:  jamestown
# Snow KeyError Received for:  jamestown
# Processing Record 3 of Set 4 | sennoy
# Rain KeyError Received for:  sennoy
# Snow KeyError Received for:  sennoy
# Processing Record 4 of Set 4 | cordoba
# Rain KeyError Received for:  cordoba
# Snow KeyError Received for:  cordoba
# Processing Record 5 of Set 4 | faanui
# Rain KeyError Received for:  faanui
# Snow KeyError Received for:  faanui
# Processing Record 6 of Set 4 | fort nelson
# Rain KeyError Received for:  fort nelson
# Snow KeyError Received for:  fort nelson
# Processing Record 7 of Set 4 | mathbaria
# Rain KeyError Received for:  mathbaria
# Snow KeyError Received for:  mathbaria
# Processing Record 8 of Set 4 | ierapetra
# Rain KeyError Received for:  ierapetra
# Snow KeyError Received for:  ierapetra
# Processing Record 9 of Set 4 | ancud
# Rain KeyError Received for:  ancud
# Snow KeyError Received for:  ancud
# Processing Record 10 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 11 of Set 4 | rezekne
# Rain KeyError Received for:  rezekne
# Snow KeyError Received for:  rezekne
# Processing Record 12 of Set 4 | lavrentiya
# Rain KeyError Received for:  lavrentiya
# Snow KeyError Received for:  lavrentiya
# Processing Record 13 of Set 4 | rocha
# Rain KeyError Received for:  rocha
# Snow KeyError Received for:  rocha
# Processing Record 14 of Set 4 | huarmey
# Rain KeyError Received for:  huarmey
# Snow KeyError Received for:  huarmey
# Processing Record 15 of Set 4 | dinar
# Rain KeyError Received for:  dinar
# Snow KeyError Received for:  dinar
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | jaru
# Rain KeyError Received for:  jaru
# Snow KeyError Received for:  jaru
# Processing Record 18 of Set 4 | dosso
# Snow KeyError Received for:  dosso
# Processing Record 19 of Set 4 | bundaberg
# Rain KeyError Received for:  bundaberg
# Snow KeyError Received for:  bundaberg
# Processing Record 20 of Set 4 | axim
# Rain KeyError Received for:  axim
# Snow KeyError Received for:  axim
# Processing Record 21 of Set 4 | wolsztyn
# Rain KeyError Received for:  wolsztyn
# Snow KeyError Received for:  wolsztyn
# Processing Record 22 of Set 4 | marang
# Rain KeyError Received for:  marang
# Snow KeyError Received for:  marang
# Processing Record 23 of Set 4 | khatanga
# Rain KeyError Received for:  khatanga
# Snow KeyError Received for:  khatanga
# Processing Record 24 of Set 4 | paamiut
# Rain KeyError Received for:  paamiut
# Snow KeyError Received for:  paamiut
# Processing Record 25 of Set 4 | muros
# Rain KeyError Received for:  muros
# Snow KeyError Received for:  muros
# Processing Record 26 of Set 4 | severo-kurilsk
# Snow KeyError Received for:  severo-kurilsk
# Processing Record 27 of Set 4 | lorengau
# Snow KeyError Received for:  lorengau
# Processing Record 28 of Set 4 | kupang
# Rain KeyError Received for:  kupang
# Snow KeyError Received for:  kupang
# Processing Record 29 of Set 4 | iskateley
# Rain KeyError Received for:  iskateley
# Snow KeyError Received for:  iskateley
# Processing Record 30 of Set 4 | klyuchi
# Rain KeyError Received for:  klyuchi
# Snow KeyError Received for:  klyuchi
# Processing Record 31 of Set 4 | ilulissat
# Rain KeyError Received for:  ilulissat
# Snow KeyError Received for:  ilulissat
# Processing Record 32 of Set 4 | pisco
# Rain KeyError Received for:  pisco
# Snow KeyError Received for:  pisco
# Processing Record 33 of Set 4 | veinticinco de mayo
# Rain KeyError Received for:  veinticinco de mayo
# Snow KeyError Received for:  veinticinco de mayo
# Processing Record 34 of Set 4 | fairbanks
# Rain KeyError Received for:  fairbanks
# Snow KeyError Received for:  fairbanks
# Processing Record 35 of Set 4 | chaykovskiy
# Snow KeyError Received for:  chaykovskiy
# Processing Record 36 of Set 4 | teya
# Snow KeyError Received for:  teya
# Processing Record 37 of Set 4 | sao joao da barra
# Rain KeyError Received for:  sao joao da barra
# Snow KeyError Received for:  sao joao da barra
# Processing Record 38 of Set 4 | thompson
# Rain KeyError Received for:  thompson
# Snow KeyError Received for:  thompson
# Processing Record 39 of Set 4 | mount isa
# Rain KeyError Received for:  mount isa
# Snow KeyError Received for:  mount isa
# Processing Record 40 of Set 4 | lagoa
# Rain KeyError Received for:  lagoa
# Snow KeyError Received for:  lagoa
# Processing Record 41 of Set 4 | vicuna
# Rain KeyError Received for:  vicuna
# Snow KeyError Received for:  vicuna
# Processing Record 42 of Set 4 | luderitz
# Rain KeyError Received for:  luderitz
# Snow KeyError Received for:  luderitz
# Processing Record 43 of Set 4 | codrington
# Rain KeyError Received for:  codrington
# Snow KeyError Received for:  codrington
# Processing Record 44 of Set 4 | camacha
# Rain KeyError Received for:  camacha
# Snow KeyError Received for:  camacha
# Processing Record 45 of Set 4 | iqaluit
# Rain KeyError Received for:  iqaluit
# Snow KeyError Received for:  iqaluit
# Processing Record 46 of Set 4 | buenos aires
# Rain KeyError Received for:  buenos aires
# Snow KeyError Received for:  buenos aires
# Processing Record 47 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 4 | brae
# Rain KeyError Received for:  brae
# Snow KeyError Received for:  brae
# Processing Record 49 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | kodiak
# Rain KeyError Received for:  kodiak
# Snow KeyError Received for:  kodiak
# Processing Record 1 of Set 5 | labuan
# Rain KeyError Received for:  labuan
# Snow KeyError Received for:  labuan
# Processing Record 2 of Set 5 | saint-philippe
# Snow KeyError Received for:  saint-philippe
# Processing Record 3 of Set 5 | anito
# Rain KeyError Received for:  anito
# Snow KeyError Received for:  anito
# Processing Record 4 of Set 5 | ayan
# Rain KeyError Received for:  ayan
# Snow KeyError Received for:  ayan
# Processing Record 5 of Set 5 | cayenne
# Rain KeyError Received for:  cayenne
# Snow KeyError Received for:  cayenne
# Processing Record 6 of Set 5 | comodoro rivadavia
# Rain KeyError Received for:  comodoro rivadavia
# Snow KeyError Received for:  comodoro rivadavia
# Processing Record 7 of Set 5 | nouakchott
# Rain KeyError Received for:  nouakchott
# Snow KeyError Received for:  nouakchott
# Processing Record 8 of Set 5 | nizwa
# Rain KeyError Received for:  nizwa
# Snow KeyError Received for:  nizwa
# Processing Record 9 of Set 5 | norman wells
# Rain KeyError Received for:  norman wells
# Snow KeyError Received for:  norman wells
# Processing Record 10 of Set 5 | ondangwa
# Rain KeyError Received for:  ondangwa
# Snow KeyError Received for:  ondangwa
# Processing Record 11 of Set 5 | aswan
# Rain KeyError Received for:  aswan
# Snow KeyError Received for:  aswan
# Processing Record 12 of Set 5 | mazamari
# Rain KeyError Received for:  mazamari
# Snow KeyError Received for:  mazamari
# Processing Record 13 of Set 5 | bambous virieux
# Rain KeyError Received for:  bambous virieux
# Snow KeyError Received for:  bambous virieux
# Processing Record 14 of Set 5 | sobinka
# Rain KeyError Received for:  sobinka
# Snow KeyError Received for:  sobinka
# Processing Record 15 of Set 5 | talnakh
# Rain KeyError Received for:  talnakh
# Snow KeyError Received for:  talnakh
# Processing Record 16 of Set 5 | severo-yeniseyskiy
# Snow KeyError Received for:  severo-yeniseyskiy
# Processing Record 17 of Set 5 | lincoln
# Rain KeyError Received for:  lincoln
# Snow KeyError Received for:  lincoln
# Processing Record 18 of Set 5 | peniche
# Rain KeyError Received for:  peniche
# Snow KeyError Received for:  peniche
# Processing Record 19 of Set 5 | nantucket
# Rain KeyError Received for:  nantucket
# Snow KeyError Received for:  nantucket
# Processing Record 20 of Set 5 | goderich
# Snow KeyError Received for:  goderich
# Processing Record 21 of Set 5 | bay roberts
# Rain KeyError Received for:  bay roberts
# Snow KeyError Received for:  bay roberts
# Processing Record 22 of Set 5 | pecos
# Rain KeyError Received for:  pecos
# Snow KeyError Received for:  pecos
# Processing Record 23 of Set 5 | saquena
# Snow KeyError Received for:  saquena
# Processing Record 24 of Set 5 | gweta
# Rain KeyError Received for:  gweta
# Snow KeyError Received for:  gweta
# Processing Record 25 of Set 5 | katsuura
# Rain KeyError Received for:  katsuura
# Snow KeyError Received for:  katsuura
# Processing Record 26 of Set 5 | vanimo
# Snow KeyError Received for:  vanimo
# Processing Record 27 of Set 5 | san vicente
# Rain KeyError Received for:  san vicente
# Snow KeyError Received for:  san vicente
# Processing Record 28 of Set 5 | jizan
# Rain KeyError Received for:  jizan
# Snow KeyError Received for:  jizan
# Processing Record 29 of Set 5 | hasaki
# Rain KeyError Received for:  hasaki
# Snow KeyError Received for:  hasaki
# Processing Record 30 of Set 5 | kasugai
# Snow KeyError Received for:  kasugai
# Processing Record 31 of Set 5 | tuktoyaktuk
# Rain KeyError Received for:  tuktoyaktuk
# Snow KeyError Received for:  tuktoyaktuk
# Processing Record 32 of Set 5 | kribi
# Snow KeyError Received for:  kribi
# Processing Record 33 of Set 5 | irtyshskiy
# Rain KeyError Received for:  irtyshskiy
# Snow KeyError Received for:  irtyshskiy
# Processing Record 34 of Set 5 | dhaka
# Rain KeyError Received for:  dhaka
# Snow KeyError Received for:  dhaka
# Processing Record 35 of Set 5 | kavieng
# Rain KeyError Received for:  kavieng
# Snow KeyError Received for:  kavieng
# Processing Record 36 of Set 5 | salalah
# Rain KeyError Received for:  salalah
# Snow KeyError Received for:  salalah
# Processing Record 37 of Set 5 | sainte-marie
# Rain KeyError Received for:  sainte-marie
# Snow KeyError Received for:  sainte-marie
# Processing Record 38 of Set 5 | hilo
# Rain KeyError Received for:  hilo
# Snow KeyError Received for:  hilo
# Processing Record 39 of Set 5 | kirksville
# Rain KeyError Received for:  kirksville
# Snow KeyError Received for:  kirksville
# Processing Record 40 of Set 5 | nepa nagar
# Rain KeyError Received for:  nepa nagar
# Snow KeyError Received for:  nepa nagar
# Processing Record 41 of Set 5 | kirakira
# Rain KeyError Received for:  kirakira
# Snow KeyError Received for:  kirakira
# Processing Record 42 of Set 5 | madisonville
# Rain KeyError Received for:  madisonville
# Snow KeyError Received for:  madisonville
# Processing Record 43 of Set 5 | esperance
# Rain KeyError Received for:  esperance
# Snow KeyError Received for:  esperance
# Processing Record 44 of Set 5 | yellowknife
# Rain KeyError Received for:  yellowknife
# Snow KeyError Received for:  yellowknife
# Processing Record 45 of Set 5 | tiznit
# Rain KeyError Received for:  tiznit
# Snow KeyError Received for:  tiznit
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | igarka
# Rain KeyError Received for:  igarka
# Snow KeyError Received for:  igarka
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 5 | smiths falls
# Rain KeyError Received for:  smiths falls
# Snow KeyError Received for:  smiths falls
# Processing Record 1 of Set 6 | geraldton
# Rain KeyError Received for:  geraldton
# Snow KeyError Received for:  geraldton
# Processing Record 2 of Set 6 | skibbereen
# Rain KeyError Received for:  skibbereen
# Snow KeyError Received for:  skibbereen
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | bamberg
# Rain KeyError Received for:  bamberg
# Snow KeyError Received for:  bamberg
# Processing Record 5 of Set 6 | plettenberg bay
# Rain KeyError Received for:  plettenberg bay
# Snow KeyError Received for:  plettenberg bay
# Processing Record 6 of Set 6 | jalu
# Rain KeyError Received for:  jalu
# Snow KeyError Received for:  jalu
# Processing Record 7 of Set 6 | placido de castro
# Rain KeyError Received for:  placido de castro
# Snow KeyError Received for:  placido de castro
# Processing Record 8 of Set 6 | chuy
# Rain KeyError Received for:  chuy
# Snow KeyError Received for:  chuy
# Processing Record 9 of Set 6 | east london
# Rain KeyError Received for:  east london
# Snow KeyError Received for:  east london
# Processing Record 10 of Set 6 | isangel
# Rain KeyError Received for:  isangel
# Snow KeyError Received for:  isangel
# Processing Record 11 of Set 6 | doha
# Rain KeyError Received for:  doha
# Snow KeyError Received for:  doha
# Processing Record 12 of Set 6 | broken hill
# Rain KeyError Received for:  broken hill
# Snow KeyError Received for:  broken hill
# Processing Record 13 of Set 6 | nome
# Rain KeyError Received for:  nome
# Snow KeyError Received for:  nome
# Processing Record 14 of Set 6 | nong bua
# Rain KeyError Received for:  nong bua
# Snow KeyError Received for:  nong bua
# Processing Record 15 of Set 6 | laguna
# Rain KeyError Received for:  laguna
# Snow KeyError Received for:  laguna
# Processing Record 16 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 6 | samarai
# Snow KeyError Received for:  samarai
# Processing Record 18 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 6 | port macquarie
# Rain KeyError Received for:  port macquarie
# Snow KeyError Received for:  port macquarie
# Processing Record 20 of Set 6 | morant bay
# Rain KeyError Received for:  morant bay
# Snow KeyError Received for:  morant bay
# Processing Record 21 of Set 6 | half moon bay
# Rain KeyError Received for:  half moon bay
# Snow KeyError Received for:  half moon bay
# Processing Record 22 of Set 6 | port lincoln
# Rain KeyError Received for:  port lincoln
# Snow KeyError Received for:  port lincoln
# Processing Record 23 of Set 6 | college
# Rain KeyError Received for:  college
# Snow KeyError Received for:  college
# Processing Record 24 of Set 6 | nioki
# Rain KeyError Received for:  nioki
# Snow KeyError Received for:  nioki
# Processing Record 25 of Set 6 | canberra
# Snow KeyError Received for:  canberra
# Processing Record 26 of Set 6 | brainerd
# Rain KeyError Received for:  brainerd
# Snow KeyError Received for:  brainerd
# Processing Record 27 of Set 6 | carutapera
# Rain KeyError Received for:  carutapera
# Snow KeyError Received for:  carutapera
# Processing Record 28 of Set 6 | upernavik
# Rain KeyError Received for:  upernavik
# Snow KeyError Received for:  upernavik
# Processing Record 29 of Set 6 | grigoropolisskaya
# Rain KeyError Received for:  grigoropolisskaya
# Snow KeyError Received for:  grigoropolisskaya
# Processing Record 30 of Set 6 | inhambane
# Rain KeyError Received for:  inhambane
# Snow KeyError Received for:  inhambane
# Processing Record 31 of Set 6 | yulara
# Rain KeyError Received for:  yulara
# Snow KeyError Received for:  yulara
# Processing Record 32 of Set 6 | vostok
# Rain KeyError Received for:  vostok
# Snow KeyError Received for:  vostok
# Processing Record 33 of Set 6 | andilamena
# Rain KeyError Received for:  andilamena
# Snow KeyError Received for:  andilamena
# Processing Record 34 of Set 6 | zhuanghe
# Rain KeyError Received for:  zhuanghe
# Snow KeyError Received for:  zhuanghe
# Processing Record 35 of Set 6 | ajdabiya
# Rain KeyError Received for:  ajdabiya
# Snow KeyError Received for:  ajdabiya
# Processing Record 36 of Set 6 | yumen
# Rain KeyError Received for:  yumen
# Snow KeyError Received for:  yumen
# Processing Record 37 of Set 6 | parintins
# Rain KeyError Received for:  parintins
# Snow KeyError Received for:  parintins
# Processing Record 38 of Set 6 | great yarmouth
# Rain KeyError Received for:  great yarmouth
# Snow KeyError Received for:  great yarmouth
# Processing Record 39 of Set 6 | saint-pierre
# Rain KeyError Received for:  saint-pierre
# Snow KeyError Received for:  saint-pierre
# Processing Record 40 of Set 6 | watsa
# Snow KeyError Received for:  watsa
# Processing Record 41 of Set 6 | juneau
# Rain KeyError Received for:  juneau
# Snow KeyError Received for:  juneau
# Processing Record 42 of Set 6 | polovinnoye
# Snow KeyError Received for:  polovinnoye
# Processing Record 43 of Set 6 | nouadhibou
# Rain KeyError Received for:  nouadhibou
# Snow KeyError Received for:  nouadhibou
# Processing Record 44 of Set 6 | tasiilaq
# Rain KeyError Received for:  tasiilaq
# Snow KeyError Received for:  tasiilaq
# Processing Record 45 of Set 6 | cidreira
# Rain KeyError Received for:  cidreira
# Snow KeyError Received for:  cidreira
# Processing Record 46 of Set 6 | buraydah
# Rain KeyError Received for:  buraydah
# Snow KeyError Received for:  buraydah
# Processing Record 47 of Set 6 | saint anthony
# Rain KeyError Received for:  saint anthony
# Snow KeyError Received for:  saint anthony
# Processing Record 48 of Set 6 | port keats
# Rain KeyError Received for:  port keats
# Snow KeyError Received for:  port keats
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | westport
# Snow KeyError Received for:  westport
# Processing Record 1 of Set 7 | wencheng
# Rain KeyError Received for:  wencheng
# Snow KeyError Received for:  wencheng
# Processing Record 2 of Set 7 | krasnoarmeyskoye
# Rain KeyError Received for:  krasnoarmeyskoye
# Snow KeyError Received for:  krasnoarmeyskoye
# Processing Record 3 of Set 7 | sur
# Rain KeyError Received for:  sur
# Snow KeyError Received for:  sur
# Processing Record 4 of Set 7 | synya
# Snow KeyError Received for:  synya
# Processing Record 5 of Set 7 | jawhar
# Rain KeyError Received for:  jawhar
# Snow KeyError Received for:  jawhar
# Processing Record 6 of Set 7 | pemberton
# Rain KeyError Received for:  pemberton
# Snow KeyError Received for:  pemberton
# Processing Record 7 of Set 7 | lompoc
# Rain KeyError Received for:  lompoc
# Snow KeyError Received for:  lompoc
# Processing Record 8 of Set 7 | narsaq
# Rain KeyError Received for:  narsaq
# Snow KeyError Received for:  narsaq
# Processing Record 9 of Set 7 | cockburn town
# Rain KeyError Received for:  cockburn town
# Snow KeyError Received for:  cockburn town
# Processing Record 10 of Set 7 | tenango
# Rain KeyError Received for:  tenango
# Snow KeyError Received for:  tenango
# Processing Record 11 of Set 7 | jumla
# Rain KeyError Received for:  jumla
# Snow KeyError Received for:  jumla
# Processing Record 12 of Set 7 | batticaloa
# Rain KeyError Received for:  batticaloa
# Snow KeyError Received for:  batticaloa
# Processing Record 13 of Set 7 | sheopur
# Rain KeyError Received for:  sheopur
# Snow KeyError Received for:  sheopur
# Processing Record 14 of Set 7 | karratha
# Rain KeyError Received for:  karratha
# Snow KeyError Received for:  karratha
# Processing Record 15 of Set 7 | chitral
# Rain KeyError Received for:  chitral
# Snow KeyError Received for:  chitral
# Processing Record 16 of Set 7 | atar
# Rain KeyError Received for:  atar
# Snow KeyError Received for:  atar
# Processing Record 17 of Set 7 | ixtapa
# Rain KeyError Received for:  ixtapa
# Snow KeyError Received for:  ixtapa
# Processing Record 18 of Set 7 | harrison
# Snow KeyError Received for:  harrison
# Processing Record 19 of Set 7 | yuanping
# Rain KeyError Received for:  yuanping
# Snow KeyError Received for:  yuanping
# Processing Record 20 of Set 7 | new norfolk
# Rain KeyError Received for:  new norfolk
# Snow KeyError Received for:  new norfolk
# Processing Record 21 of Set 7 | sao francisco
# Rain KeyError Received for:  sao francisco
# Snow KeyError Received for:  sao francisco
# Processing Record 22 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 7 | senador jose porfirio
# Rain KeyError Received for:  senador jose porfirio
# Snow KeyError Received for:  senador jose porfirio
# Processing Record 24 of Set 7 | mangit
# Rain KeyError Received for:  mangit
# Snow KeyError Received for:  mangit
# Processing Record 25 of Set 7 | tori
# Rain KeyError Received for:  tori
# Snow KeyError Received for:  tori
# Processing Record 26 of Set 7 | westerland
# Rain KeyError Received for:  westerland
# Snow KeyError Received for:  westerland
# Processing Record 27 of Set 7 | maracas
# Rain KeyError Received for:  maracas
# Snow KeyError Received for:  maracas
# Processing Record 28 of Set 7 | wanderlandia
# City not found. Skipping...
# Processing Record 29 of Set 7 | mangrol
# Snow KeyError Received for:  mangrol
# Processing Record 30 of Set 7 | bairiki
# Rain KeyError Received for:  bairiki
# Snow KeyError Received for:  bairiki
# Processing Record 31 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 7 | gravdal
# Rain KeyError Received for:  gravdal
# Snow KeyError Received for:  gravdal
# Processing Record 33 of Set 7 | olafsvik
# Rain KeyError Received for:  olafsvik
# Snow KeyError Received for:  olafsvik
# Processing Record 34 of Set 7 | roebourne
# Rain KeyError Received for:  roebourne
# Snow KeyError Received for:  roebourne
# Processing Record 35 of Set 7 | forestville
# Rain KeyError Received for:  forestville
# Snow KeyError Received for:  forestville
# Processing Record 36 of Set 7 | zeya
# Rain KeyError Received for:  zeya
# Snow KeyError Received for:  zeya
# Processing Record 37 of Set 7 | dhidhdhoo
# Snow KeyError Received for:  dhidhdhoo
# Processing Record 38 of Set 7 | akniste
# Rain KeyError Received for:  akniste
# Snow KeyError Received for:  akniste
# Processing Record 39 of Set 7 | riverton
# Rain KeyError Received for:  riverton
# Snow KeyError Received for:  riverton
# Processing Record 40 of Set 7 | marathon
# Rain KeyError Received for:  marathon
# Snow KeyError Received for:  marathon
# Processing Record 41 of Set 7 | ullal
# Rain KeyError Received for:  ullal
# Snow KeyError Received for:  ullal
# Processing Record 42 of Set 7 | hachinohe
# Rain KeyError Received for:  hachinohe
# Snow KeyError Received for:  hachinohe
# Processing Record 43 of Set 7 | dongsheng
# Rain KeyError Received for:  dongsheng
# Snow KeyError Received for:  dongsheng
# Processing Record 44 of Set 7 | south sioux city
# Rain KeyError Received for:  south sioux city
# Snow KeyError Received for:  south sioux city
# Processing Record 45 of Set 7 | songjianghe
# Rain KeyError Received for:  songjianghe
# Snow KeyError Received for:  songjianghe
# Processing Record 46 of Set 7 | ust-tarka
# Rain KeyError Received for:  ust-tarka
# Snow KeyError Received for:  ust-tarka
# Processing Record 47 of Set 7 | vardo
# Rain KeyError Received for:  vardo
# Snow KeyError Received for:  vardo
# Processing Record 48 of Set 7 | khao yoi
# Rain KeyError Received for:  khao yoi
# Snow KeyError Received for:  khao yoi
# Processing Record 49 of Set 7 | mackay
# Rain KeyError Received for:  mackay
# Snow KeyError Received for:  mackay
# Processing Record 50 of Set 7 | srednekolymsk
# Rain KeyError Received for:  srednekolymsk
# Snow KeyError Received for:  srednekolymsk
# Processing Record 1 of Set 8 | port augusta
# Rain KeyError Received for:  port augusta
# Snow KeyError Received for:  port augusta
# Processing Record 2 of Set 8 | riyadh
# Rain KeyError Received for:  riyadh
# Snow KeyError Received for:  riyadh
# Processing Record 3 of Set 8 | methoni
# Rain KeyError Received for:  methoni
# Snow KeyError Received for:  methoni
# Processing Record 4 of Set 8 | seoul
# Rain KeyError Received for:  seoul
# Snow KeyError Received for:  seoul
# Processing Record 5 of Set 8 | chara
# Rain KeyError Received for:  chara
# Snow KeyError Received for:  chara
# Processing Record 6 of Set 8 | panaba
# Snow KeyError Received for:  panaba
# Processing Record 7 of Set 8 | bulgan
# Rain KeyError Received for:  bulgan
# Snow KeyError Received for:  bulgan
# Processing Record 8 of Set 8 | san andres
# Rain KeyError Received for:  san andres
# Snow KeyError Received for:  san andres
# Processing Record 9 of Set 8 | melilla
# Rain KeyError Received for:  melilla
# Snow KeyError Received for:  melilla
# Processing Record 10 of Set 8 | pangnirtung
# Rain KeyError Received for:  pangnirtung
# Snow KeyError Received for:  pangnirtung
# Processing Record 11 of Set 8 | lugovoy
# Rain KeyError Received for:  lugovoy
# Snow KeyError Received for:  lugovoy
# Processing Record 12 of Set 8 | champerico
# Rain KeyError Received for:  champerico
# Snow KeyError Received for:  champerico
# Processing Record 13 of Set 8 | shimanovsk
# Rain KeyError Received for:  shimanovsk
# Snow KeyError Received for:  shimanovsk
# Processing Record 14 of Set 8 | bambanglipuro
# Snow KeyError Received for:  bambanglipuro
# Processing Record 15 of Set 8 | dunedin
# Rain KeyError Received for:  dunedin
# Snow KeyError Received for:  dunedin
# Processing Record 16 of Set 8 | adrar
# Rain KeyError Received for:  adrar
# Snow KeyError Received for:  adrar
# Processing Record 17 of Set 8 | khash
# Rain KeyError Received for:  khash
# Snow KeyError Received for:  khash
# Processing Record 18 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 8 | poronaysk
# Rain KeyError Received for:  poronaysk
# Snow KeyError Received for:  poronaysk
# Processing Record 20 of Set 8 | bayanday
# Rain KeyError Received for:  bayanday
# Snow KeyError Received for:  bayanday
# Processing Record 21 of Set 8 | belmonte
# Rain KeyError Received for:  belmonte
# Snow KeyError Received for:  belmonte
# Processing Record 22 of Set 8 | puerto palomas
# Rain KeyError Received for:  puerto palomas
# Snow KeyError Received for:  puerto palomas
# Processing Record 23 of Set 8 | bereda
# Rain KeyError Received for:  bereda
# Snow KeyError Received for:  bereda
# Processing Record 24 of Set 8 | timberlake
# Rain KeyError Received for:  timberlake
# Snow KeyError Received for:  timberlake
# Processing Record 25 of Set 8 | balkhash
# Rain KeyError Received for:  balkhash
# Snow KeyError Received for:  balkhash
# Processing Record 26 of Set 8 | phalaborwa
# Rain KeyError Received for:  phalaborwa
# Snow KeyError Received for:  phalaborwa
# Processing Record 27 of Set 8 | hami
# Rain KeyError Received for:  hami
# Snow KeyError Received for:  hami
# Processing Record 28 of Set 8 | vila
# Rain KeyError Received for:  vila
# Snow KeyError Received for:  vila
# Processing Record 29 of Set 8 | altamira
# Rain KeyError Received for:  altamira
# Snow KeyError Received for:  altamira
# Processing Record 30 of Set 8 | tiksi
# Rain KeyError Received for:  tiksi
# Snow KeyError Received for:  tiksi
# Processing Record 31 of Set 8 | pitimbu
# Rain KeyError Received for:  pitimbu
# Snow KeyError Received for:  pitimbu
# Processing Record 32 of Set 8 | vila velha
# Rain KeyError Received for:  vila velha
# Snow KeyError Received for:  vila velha
# Processing Record 33 of Set 8 | great falls
# Rain KeyError Received for:  great falls
# Snow KeyError Received for:  great falls
# Processing Record 34 of Set 8 | new amsterdam
# Snow KeyError Received for:  new amsterdam
# Processing Record 35 of Set 8 | yar-sale
# Rain KeyError Received for:  yar-sale
# Snow KeyError Received for:  yar-sale
# Processing Record 36 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 37 of Set 8 | sorong
# Snow KeyError Received for:  sorong
# Processing Record 38 of Set 8 | baghdad
# Rain KeyError Received for:  baghdad
# Snow KeyError Received for:  baghdad
# Processing Record 39 of Set 8 | gladstone
# Rain KeyError Received for:  gladstone
# Snow KeyError Received for:  gladstone
# Processing Record 40 of Set 8 | point pedro
# Snow KeyError Received for:  point pedro
# Processing Record 41 of Set 8 | constitucion
# Rain KeyError Received for:  constitucion
# Snow KeyError Received for:  constitucion
# Processing Record 42 of Set 8 | roald
# Rain KeyError Received for:  roald
# Snow KeyError Received for:  roald
# Processing Record 43 of Set 8 | fare
# Rain KeyError Received for:  fare
# Snow KeyError Received for:  fare
# Processing Record 44 of Set 8 | chifeng
# Rain KeyError Received for:  chifeng
# Snow KeyError Received for:  chifeng
# Processing Record 45 of Set 8 | aboisso
# Rain KeyError Received for:  aboisso
# Snow KeyError Received for:  aboisso
# Processing Record 46 of Set 8 | petlawad
# Rain KeyError Received for:  petlawad
# Snow KeyError Received for:  petlawad
# Processing Record 47 of Set 8 | umm kaddadah
# Snow KeyError Received for:  umm kaddadah
# Processing Record 48 of Set 8 | esil
# Rain KeyError Received for:  esil
# Snow KeyError Received for:  esil
# Processing Record 49 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 50 of Set 8 | kieta
# Snow KeyError Received for:  kieta
# Processing Record 1 of Set 9 | burica
# City not found. Skipping...
# Processing Record 2 of Set 9 | quatre cocos
# Rain KeyError Received for:  quatre cocos
# Snow KeyError Received for:  quatre cocos
# Processing Record 3 of Set 9 | lulea
# Rain KeyError Received for:  lulea
# Snow KeyError Received for:  lulea
# Processing Record 4 of Set 9 | kenai
# Rain KeyError Received for:  kenai
# Snow KeyError Received for:  kenai
# Processing Record 5 of Set 9 | unity
# Snow KeyError Received for:  unity
# Processing Record 6 of Set 9 | poyarkovo
# Rain KeyError Received for:  poyarkovo
# Snow KeyError Received for:  poyarkovo
# Processing Record 7 of Set 9 | agirish
# Rain KeyError Received for:  agirish
# Snow KeyError Received for:  agirish
# Processing Record 8 of Set 9 | kamenka
# Rain KeyError Received for:  kamenka
# Snow KeyError Received for:  kamenka
# Processing Record 9 of Set 9 | puerto escondido
# Rain KeyError Received for:  puerto escondido
# Snow KeyError Received for:  puerto escondido
# Processing Record 10 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 9 | tigre
# Rain KeyError Received for:  tigre
# Snow KeyError Received for:  tigre
# Processing Record 12 of Set 9 | skelleftea
# Rain KeyError Received for:  skelleftea
# Snow KeyError Received for:  skelleftea
# Processing Record 13 of Set 9 | antalya
# Rain KeyError Received for:  antalya
# Snow KeyError Received for:  antalya
# Processing Record 14 of Set 9 | ketchikan
# Snow KeyError Received for:  ketchikan
# Processing Record 15 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 9 | tazovskiy
# Rain KeyError Received for:  tazovskiy
# Snow KeyError Received for:  tazovskiy
# Processing Record 17 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 9 | yvetot
# Rain KeyError Received for:  yvetot
# Snow KeyError Received for:  yvetot
# Processing Record 19 of Set 9 | antofagasta
# Rain KeyError Received for:  antofagasta
# Snow KeyError Received for:  antofagasta
# Processing Record 20 of Set 9 | georgetown
# Rain KeyError Received for:  georgetown
# Snow KeyError Received for:  georgetown
# Processing Record 21 of Set 9 | nata
# Rain KeyError Received for:  nata
# Snow KeyError Received for:  nata
# Processing Record 22 of Set 9 | araouane
# Snow KeyError Received for:  araouane
# Processing Record 23 of Set 9 | karangasem
# Rain KeyError Received for:  karangasem
# Snow KeyError Received for:  karangasem
# Processing Record 24 of Set 9 | marsh harbour
# Rain KeyError Received for:  marsh harbour
# Snow KeyError Received for:  marsh harbour
# Processing Record 25 of Set 9 | marawi
# Rain KeyError Received for:  marawi
# Snow KeyError Received for:  marawi
# Processing Record 26 of Set 9 | acajutla
# Snow KeyError Received for:  acajutla
# Processing Record 27 of Set 9 | bonavista
# Snow KeyError Received for:  bonavista
# Processing Record 28 of Set 9 | glendive
# Rain KeyError Received for:  glendive
# Snow KeyError Received for:  glendive
# Processing Record 29 of Set 9 | bilma
# Rain KeyError Received for:  bilma
# Snow KeyError Received for:  bilma
# Processing Record 30 of Set 9 | bubaque
# Snow KeyError Received for:  bubaque
# Processing Record 31 of Set 9 | mehtar lam
# Rain KeyError Received for:  mehtar lam
# Snow KeyError Received for:  mehtar lam
# Processing Record 32 of Set 9 | yook
# Snow KeyError Received for:  yook
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Rain KeyError Received for:  petropavlovsk-kamchatskiy
# Snow KeyError Received for:  petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | smithers
# Rain KeyError Received for:  smithers
# Snow KeyError Received for:  smithers
# Processing Record 35 of Set 9 | brownfield
# Rain KeyError Received for:  brownfield
# Snow KeyError Received for:  brownfield
# Processing Record 36 of Set 9 | corsicana
# Rain KeyError Received for:  corsicana
# Snow KeyError Received for:  corsicana
# Processing Record 37 of Set 9 | evensk
# Snow KeyError Received for:  evensk
# Processing Record 38 of Set 9 | yeppoon
# Rain KeyError Received for:  yeppoon
# Snow KeyError Received for:  yeppoon
# Processing Record 39 of Set 9 | shingu
# Snow KeyError Received for:  shingu
# ...
# Processing Record 12 of Set 10 | middelburg
# Rain KeyError Received for:  middelburg
# Snow KeyError Received for:  middelburg
# Processing Record 13 of Set 10 | flin flon
# Rain KeyError Received for:  flin flon
# Snow KeyError Received for:  flin flon
# Processing Record 14 of Set 10 | majene
# Rain KeyError Received for:  majene
# Snow KeyError Received for:  majene
# Processing Record 15 of Set 10 | bethel
# Rain KeyError Received for:  bethel
# Snow KeyError Received for:  bethel
# Processing Record 16 of Set 10 | muyezerskiy
# Rain KeyError Received for:  muyezerskiy
# Snow KeyError Received for:  muyezerskiy
# Processing Record 17 of Set 10 | shunyi
# Rain KeyError Received for:  shunyi
# Snow KeyError Received for:  shunyi
# Processing Record 18 of Set 10 | ust-ishim
# Rain KeyError Received for:  ust-ishim
# Snow KeyError Received for:  ust-ishim
# Processing Record 19 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 10 | grand-santi
# Snow KeyError Received for:  grand-santi
# Processing Record 21 of Set 10 | san patricio
# Rain KeyError Received for:  san patricio
# Snow KeyError Received for:  san patricio
# Processing Record 22 of Set 10 | egersund
# Rain KeyError Received for:  egersund
# Snow KeyError Received for:  egersund
# Processing Record 23 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 10 | jieshi
# Rain KeyError Received for:  jieshi
# Snow KeyError Received for:  jieshi
# Processing Record 25 of Set 10 | ondjiva
# Rain KeyError Received for:  ondjiva
# Snow KeyError Received for:  ondjiva
# Processing Record 26 of Set 10 | voh
# Rain KeyError Received for:  voh
# Snow KeyError Received for:  voh
# Processing Record 27 of Set 10 | saint george
# Rain KeyError Received for:  saint george
# Snow KeyError Received for:  saint george
# Processing Record 28 of Set 10 | pokaran
# Rain KeyError Received for:  pokaran
# Snow KeyError Received for:  pokaran
# Processing Record 29 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 30 of Set 10 | caravelas
# Rain KeyError Received for:  caravelas
# Snow KeyError Received for:  caravelas
# Processing Record 31 of Set 10 | pacific grove
# Rain KeyError Received for:  pacific grove
# Snow KeyError Received for:  pacific grove
# Processing Record 32 of Set 10 | camocim
# Rain KeyError Received for:  camocim
# Snow KeyError Received for:  camocim
# Processing Record 33 of Set 10 | kapoeta
# Rain KeyError Received for:  kapoeta
# Snow KeyError Received for:  kapoeta
# Processing Record 34 of Set 10 | kasama
# Rain KeyError Received for:  kasama
# Snow KeyError Received for:  kasama
# Processing Record 35 of Set 10 | nelson bay
# Rain KeyError Received for:  nelson bay
# Snow KeyError Received for:  nelson bay
# Processing Record 36 of Set 10 | imeni poliny osipenko
# Rain KeyError Received for:  imeni poliny osipenko
# Snow KeyError Received for:  imeni poliny osipenko
# Processing Record 37 of Set 10 | ekhabi
# Rain KeyError Received for:  ekhabi
# Snow KeyError Received for:  ekhabi
# Processing Record 38 of Set 10 | presidente epitacio
# Rain KeyError Received for:  presidente epitacio
# Snow KeyError Received for:  presidente epitacio
# Processing Record 39 of Set 10 | maniitsoq
# Rain KeyError Received for:  maniitsoq
# Snow KeyError Received for:  maniitsoq
# Processing Record 40 of Set 10 | waspan
# Rain KeyError Received for:  waspan
# Snow KeyError Received for:  waspan
# Processing Record 41 of Set 10 | bathsheba
# Rain KeyError Received for:  bathsheba
# Snow KeyError Received for:  bathsheba
# Processing Record 42 of Set 10 | aktau
# Rain KeyError Received for:  aktau
# Snow KeyError Received for:  aktau
# Processing Record 43 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 10 | acapulco
# Rain KeyError Received for:  acapulco
# Snow KeyError Received for:  acapulco
# Processing Record 45 of Set 10 | galesong
# Rain KeyError Received for:  galesong
# Snow KeyError Received for:  galesong
# Processing Record 46 of Set 10 | erdenet
# Rain KeyError Received for:  erdenet
# Snow KeyError Received for:  erdenet
# Processing Record 47 of Set 10 | poum
# Rain KeyError Received for:  poum
# Snow KeyError Received for:  poum
# Processing Record 48 of Set 10 | fairmount
# Rain KeyError Received for:  fairmount
# Snow KeyError Received for:  fairmount
# Processing Record 49 of Set 10 | touros
# Rain KeyError Received for:  touros
# Snow KeyError Received for:  touros
# Processing Record 50 of Set 10 | lazaro cardenas
# Rain KeyError Received for:  lazaro cardenas
# Snow KeyError Received for:  lazaro cardenas
# Processing Record 1 of Set 11 | port blair
# Rain KeyError Received for:  port blair
# Snow KeyError Received for:  port blair
# Processing Record 2 of Set 11 | murupara
# Rain KeyError Received for:  murupara
# Snow KeyError Received for:  murupara
# Processing Record 3 of Set 11 | wilmington
# Rain KeyError Received for:  wilmington
# Snow KeyError Received for:  wilmington
# Processing Record 4 of Set 11 | waingapu
# Rain KeyError Received for:  waingapu
# Snow KeyError Received for:  waingapu
# Processing Record 5 of Set 11 | tucumcari
# Rain KeyError Received for:  tucumcari
# Snow KeyError Received for:  tucumcari
# Processing Record 6 of Set 11 | zhob
# Rain KeyError Received for:  zhob
# Snow KeyError Received for:  zhob
# Processing Record 7 of Set 11 | drochia
# Rain KeyError Received for:  drochia
# Snow KeyError Received for:  drochia
# Processing Record 8 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 11 | banda aceh
# Rain KeyError Received for:  banda aceh
# Snow KeyError Received for:  banda aceh
# Processing Record 10 of Set 11 | shahr-e babak
# Rain KeyError Received for:  shahr-e babak
# Snow KeyError Received for:  shahr-e babak
# Processing Record 11 of Set 11 | isoka
# Rain KeyError Received for:  isoka
# Snow KeyError Received for:  isoka
# Processing Record 12 of Set 11 | zhigansk
# Rain KeyError Received for:  zhigansk
# Snow KeyError Received for:  zhigansk
# Processing Record 13 of Set 11 | paracuru
# Rain KeyError Received for:  paracuru
# Snow KeyError Received for:  paracuru
# Processing Record 14 of Set 11 | praia
# Rain KeyError Received for:  praia
# Snow KeyError Received for:  praia
# Processing Record 15 of Set 11 | soyo
# Rain KeyError Received for:  soyo
# Snow KeyError Received for:  soyo
# Processing Record 16 of Set 11 | indramayu
# Rain KeyError Received for:  indramayu
# Snow KeyError Received for:  indramayu
# Processing Record 17 of Set 11 | abay
# Rain KeyError Received for:  abay
# Snow KeyError Received for:  abay
# Processing Record 18 of Set 11 | yarovoye
# Rain KeyError Received for:  yarovoye
# Snow KeyError Received for:  yarovoye
# Processing Record 19 of Set 11 | nehe
# Rain KeyError Received for:  nehe
# Snow KeyError Received for:  nehe
# Processing Record 20 of Set 11 | vila franca do campo
# Rain KeyError Received for:  vila franca do campo
# Snow KeyError Received for:  vila franca do campo
# Processing Record 21 of Set 11 | acarau
# Rain KeyError Received for:  acarau
# Snow KeyError Received for:  acarau
# Processing Record 22 of Set 11 | mitchell
# Rain KeyError Received for:  mitchell
# Snow KeyError Received for:  mitchell
# Processing Record 23 of Set 11 | mogadishu
# Snow KeyError Received for:  mogadishu
# Processing Record 24 of Set 11 | humaita
# Rain KeyError Received for:  humaita
# Snow KeyError Received for:  humaita
# Processing Record 25 of Set 11 | klaksvik
# Rain KeyError Received for:  klaksvik
# Snow KeyError Received for:  klaksvik
# Processing Record 26 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 11 | quelimane
# Rain KeyError Received for:  quelimane
# Snow KeyError Received for:  quelimane
# Processing Record 28 of Set 11 | zhezkazgan
# Rain KeyError Received for:  zhezkazgan
# Snow KeyError Received for:  zhezkazgan
# Processing Record 29 of Set 11 | rudbar
# Rain KeyError Received for:  rudbar
# Snow KeyError Received for:  rudbar
# Processing Record 30 of Set 11 | masakin
# Rain KeyError Received for:  masakin
# Snow KeyError Received for:  masakin
# Processing Record 31 of Set 11 | goure
# Rain KeyError Received for:  goure
# Snow KeyError Received for:  goure
# Processing Record 32 of Set 11 | jishou
# Snow KeyError Received for:  jishou
# Processing Record 33 of Set 11 | taltal
# Rain KeyError Received for:  taltal
# Snow KeyError Received for:  taltal
# Processing Record 34 of Set 11 | jaltenango
# Snow KeyError Received for:  jaltenango
# Processing Record 35 of Set 11 | pingshan
# Snow KeyError Received for:  pingshan
# Processing Record 36 of Set 11 | lensk
# Rain KeyError Received for:  lensk
# Snow KeyError Received for:  lensk
# Processing Record 37 of Set 11 | north platte
# Rain KeyError Received for:  north platte
# Snow KeyError Received for:  north platte
# Processing Record 38 of Set 11 | opuwo
# Rain KeyError Received for:  opuwo
# Snow KeyError Received for:  opuwo
# Processing Record 39 of Set 11 | aykhal
# Rain KeyError Received for:  aykhal
# Snow KeyError Received for:  aykhal
# Processing Record 40 of Set 11 | bilimbay
# Rain KeyError Received for:  bilimbay
# Snow KeyError Received for:  bilimbay
# Processing Record 41 of Set 11 | ouadda
# Rain KeyError Received for:  ouadda
# Snow KeyError Received for:  ouadda
# Processing Record 42 of Set 11 | serebryansk
# Rain KeyError Received for:  serebryansk
# Snow KeyError Received for:  serebryansk
# Processing Record 43 of Set 11 | abapo
# Rain KeyError Received for:  abapo
# Snow KeyError Received for:  abapo
# Processing Record 44 of Set 11 | pinawa
# Rain KeyError Received for:  pinawa
# Snow KeyError Received for:  pinawa
# Processing Record 45 of Set 11 | winona
# Rain KeyError Received for:  winona
# Snow KeyError Received for:  winona
# Processing Record 46 of Set 11 | hefei
# Rain KeyError Received for:  hefei
# Snow KeyError Received for:  hefei
# Processing Record 47 of Set 11 | nanortalik
# Rain KeyError Received for:  nanortalik
# Snow KeyError Received for:  nanortalik
# Processing Record 48 of Set 11 | tarakan
# Snow KeyError Received for:  tarakan
# Processing Record 49 of Set 11 | puri
# Rain KeyError Received for:  puri
# Snow KeyError Received for:  puri
# Processing Record 50 of Set 11 | borogontsy
# Rain KeyError Received for:  borogontsy
# Snow KeyError Received for:  borogontsy
# Processing Record 1 of Set 12 | esso
# Rain KeyError Received for:  esso
# Snow KeyError Received for:  esso
# Processing Record 2 of Set 12 | tambun
# Rain KeyError Received for:  tambun
# Snow KeyError Received for:  tambun
# Processing Record 3 of Set 12 | polis
# Rain KeyError Received for:  polis
# Snow KeyError Received for:  polis
# Processing Record 4 of Set 12 | te anau
# Rain KeyError Received for:  te anau
# Snow KeyError Received for:  te anau
# Processing Record 5 of Set 12 | menongue
# Rain KeyError Received for:  menongue
# Snow KeyError Received for:  menongue
# Processing Record 6 of Set 12 | oranjemund
# Snow KeyError Received for:  oranjemund
# Processing Record 7 of Set 12 | makokou
# Snow KeyError Received for:  makokou
# Processing Record 8 of Set 12 | jiayuguan
# Rain KeyError Received for:  jiayuguan
# Snow KeyError Received for:  jiayuguan
# Processing Record 9 of Set 12 | kavaratti
# Rain KeyError Received for:  kavaratti
# Snow KeyError Received for:  kavaratti
# Processing Record 10 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 12 | caramay
# Snow KeyError Received for:  caramay
# Processing Record 12 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 13 of Set 12 | bara
# Snow KeyError Received for:  bara
# Processing Record 14 of Set 12 | moses lake
# Rain KeyError Received for:  moses lake
# Snow KeyError Received for:  moses lake
# Processing Record 15 of Set 12 | shizunai
# Rain KeyError Received for:  shizunai
# Snow KeyError Received for:  shizunai
# Processing Record 16 of Set 12 | rockwall
# Rain KeyError Received for:  rockwall
# Snow KeyError Received for:  rockwall
# Processing Record 17 of Set 12 | labytnangi
# Rain KeyError Received for:  labytnangi
# Snow KeyError Received for:  labytnangi
# Processing Record 18 of Set 12 | camacupa
# Rain KeyError Received for:  camacupa
# Snow KeyError Received for:  camacupa
# Processing Record 19 of Set 12 | outlook
# Rain KeyError Received for:  outlook
# Snow KeyError Received for:  outlook
# Processing Record 20 of Set 12 | vuktyl
# Snow KeyError Received for:  vuktyl
# Processing Record 21 of Set 12 | kailua
# Rain KeyError Received for:  kailua
# Snow KeyError Received for:  kailua
# Processing Record 22 of Set 12 | mount pleasant
# Rain KeyError Received for:  mount pleasant
# Snow KeyError Received for:  mount pleasant
# Processing Record 23 of Set 12 | mirabad
# Rain KeyError Received for:  mirabad
# Snow KeyError Received for:  mirabad
# Processing Record 24 of Set 12 | abu kamal
# Rain KeyError Received for:  abu kamal
# Snow KeyError Received for:  abu kamal
# Processing Record 25 of Set 12 | gunnedah
# Rain KeyError Received for:  gunnedah
# Snow KeyError Received for:  gunnedah
# Processing Record 26 of Set 12 | sorland
# Rain KeyError Received for:  sorland
# Snow KeyError Received for:  sorland
# Processing Record 27 of Set 12 | marienburg
# Rain KeyError Received for:  marienburg
# Snow KeyError Received for:  marienburg
# Processing Record 28 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 29 of Set 12 | sumbe
# Rain KeyError Received for:  sumbe
# Snow KeyError Received for:  sumbe
# Processing Record 30 of Set 12 | toungoo
# City not found. Skipping...
# Processing Record 31 of Set 12 | olinda
# Rain KeyError Received for:  olinda
# Snow KeyError Received for:  olinda
# Processing Record 32 of Set 12 | sanchursk
# Rain KeyError Received for:  sanchursk
# Snow KeyError Received for:  sanchursk
# Processing Record 33 of Set 12 | marzuq
# Rain KeyError Received for:  marzuq
# Snow KeyError Received for:  marzuq
# Processing Record 34 of Set 12 | broome
# Rain KeyError Received for:  broome
# Snow KeyError Received for:  broome
# Processing Record 35 of Set 12 | pringsewu
# Rain KeyError Received for:  pringsewu
# Snow KeyError Received for:  pringsewu
# Processing Record 36 of Set 12 | friesoythe
# Rain KeyError Received for:  friesoythe
# Snow KeyError Received for:  friesoythe
# Processing Record 37 of Set 12 | rawson
# Rain KeyError Received for:  rawson
# Snow KeyError Received for:  rawson
# Processing Record 38 of Set 12 | azad shahr
# Rain KeyError Received for:  azad shahr
# Snow KeyError Received for:  azad shahr
# Processing Record 39 of Set 12 | tukrah
# Rain KeyError Received for:  tukrah
# Snow KeyError Received for:  tukrah
# Processing Record 40 of Set 12 | curaca
# Rain KeyError Received for:  curaca
# Snow KeyError Received for:  curaca
# Processing Record 41 of Set 12 | komsomolskiy
# Rain KeyError Received for:  komsomolskiy
# Snow KeyError Received for:  komsomolskiy
# Processing Record 42 of Set 12 | arona
# Rain KeyError Received for:  arona
# Snow KeyError Received for:  arona
# Processing Record 43 of Set 12 | leningradskiy
# Rain KeyError Received for:  leningradskiy
# Snow KeyError Received for:  leningradskiy
# Processing Record 44 of Set 12 | abu dhabi
# Rain KeyError Received for:  abu dhabi
# Snow KeyError Received for:  abu dhabi
# Processing Record 45 of Set 12 | whitehorse
# Rain KeyError Received for:  whitehorse
# Snow KeyError Received for:  whitehorse
# Processing Record 46 of Set 12 | bure
# Snow KeyError Received for:  bure
# Processing Record 47 of Set 12 | ewa beach
# Rain KeyError Received for:  ewa beach
# Snow KeyError Received for:  ewa beach
# Processing Record 48 of Set 12 | bilibino
# Rain KeyError Received for:  bilibino
# Snow KeyError Received for:  bilibino
# Processing Record 49 of Set 12 | belaya gora
# Rain KeyError Received for:  belaya gora
# Snow KeyError Received for:  belaya gora
# Processing Record 50 of Set 12 | kopyevo
# City not found. Skipping...
# Processing Record 1 of Set 13 | kahului
# Rain KeyError Received for:  kahului
# Snow KeyError Received for:  kahului
# Processing Record 2 of Set 13 | xining
# Rain KeyError Received for:  xining
# Snow KeyError Received for:  xining
# Processing Record 3 of Set 13 | morondava
# Rain KeyError Received for:  morondava
# Snow KeyError Received for:  morondava
# Processing Record 4 of Set 13 | piranshahr
# Rain KeyError Received for:  piranshahr
# Snow KeyError Received for:  piranshahr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Determine length of city_data.  Needs to be over 500
len(city_data)
# Out:
# 555

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sosnovo-Ozerskoye  52.52  111.54     56.75        91          71
# 1              Kapaa  22.08 -159.32     82.40        69          40
# 2          Mahebourg -20.41   57.70     69.80        77          75
# 3          Cape Town -33.93   18.42     53.01        87          75
# 4            Qaanaaq  77.48  -69.36     46.24        56          76
# 5           Mazatlan  23.22 -106.42     91.40        63           5
# 6          Liverpool  53.41   -2.98     59.00        67          20
# 7            Rikitea -23.12 -134.97     67.71        65          83
# 8         Bredasdorp -34.53   20.04     51.80        87          84
# 9            Ushuaia -54.80  -68.30     33.80        80         100
#
#    Wind Speed   Current Description  Rain (inches)  Snow (inches) Country  \
# 0        4.27         broken clouds           0.00              0      RU
# 1       12.75      scattered clouds           0.00              0      US
# 2       20.80           shower rain           0.00              0      MU
# 3       16.11  heavy intensity rain           2.54              0      ZA
# 4        3.40         broken clouds           0.00              0      GL
# 5       10.29             clear sky           0.00              0      MX
# 6       16.11            few clouds           0.00              0      GB
# 7       18.99         broken clouds           0.00              0      PF
# 8        4.70         broken clouds           0.00              0      ZA
# 9        3.36       overcast clouds           0.00              0      AR
#
#                   Date
# 0  2020-07-10 19:59:04
# 1  2020-07-10 19:54:44
# 2  2020-07-10 19:59:04
# 3  2020-07-10 19:56:36
# 4  2020-07-10 19:59:04
# 5  2020-07-10 19:58:02
# 6  2020-07-10 19:56:53
# 7  2020-07-10 19:59:05
# 8  2020-07-10 19:59:06
# 9  2020-07-10 19:59:06

# %%
# Reorder columns for asthetics
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description', 'Rain (inches)', 'Snow (inches)']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sosnovo-Ozerskoye      RU  52.52  111.54     56.75        91          71
# 1              Kapaa      US  22.08 -159.32     82.40        69          40
# 2          Mahebourg      MU -20.41   57.70     69.80        77          75
# 3          Cape Town      ZA -33.93   18.42     53.01        87          75
# 4            Qaanaaq      GL  77.48  -69.36     46.24        56          76
# 5           Mazatlan      MX  23.22 -106.42     91.40        63           5
# 6          Liverpool      GB  53.41   -2.98     59.00        67          20
# 7            Rikitea      PF -23.12 -134.97     67.71        65          83
# 8         Bredasdorp      ZA -34.53   20.04     51.80        87          84
# 9            Ushuaia      AR -54.80  -68.30     33.80        80         100
#
#    Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 0        4.27         broken clouds           0.00              0
# 1       12.75      scattered clouds           0.00              0
# 2       20.80           shower rain           0.00              0
# 3       16.11  heavy intensity rain           2.54              0
# 4        3.40         broken clouds           0.00              0
# 5       10.29             clear sky           0.00              0
# 6       16.11            few clouds           0.00              0
# 7       18.99         broken clouds           0.00              0
# 8        4.70         broken clouds           0.00              0
# 9        3.36       overcast clouds           0.00              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
